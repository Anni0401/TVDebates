# %%
import torch
import pytubefix

# %%
#language = "english"
language = "german"
m4a_file = 'short_video_' + language +  '.m4a'

# %%
if language == "english":
    yt = pytubefix.YouTube("https://www.youtube.com/watch?v=f5s-Dvul22A")
else:
    yt = pytubefix.YouTube("https://www.youtube.com/watch?v=68gLTp_mIAw&t=58s")

#For abr choose the highest available one
yt.streams.filter(only_audio=True, abr="128kbps").first().download(filename=m4a_file)
# Out:
# '/Users/anniherrmann/tvdebates/short_video_german.m4a'

# %%
from pydub import AudioSegment


wav_filename = 'debate_' + language + '.wav'

sound = AudioSegment.from_file(m4a_file, format='m4a')
file_handle = sound.export(wav_filename, format='wav')

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"
torch_device = torch.device(device)
torch_dtype =  torch.float16 if torch.backends.mps.is_available() else torch.float32

# %%
with open("access_token","r") as f:
    hf_access_token = f.read()

# %%
from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained(
  "pyannote/speaker-diarization-3.1",
  use_auth_token=hf_access_token)

pipeline.to(torch_device)

# run the pipeline on an audio file
diarization = pipeline(wav_filename, num_speakers=None)

speaker_file = "timestamps_" + language + ".rttm"

# dump the diarization output to disk using RTTM format
with open(speaker_file, "w") as rttm:
    diarization.write_rttm(rttm)

# %%
for turn, _, speaker in diarization.itertracks(yield_label=True):
    print(f"start={turn.start:.1f}s stop={turn.end:.1f}s {speaker}")
# Out:
# start=0.0s stop=4.0s SPEAKER_01
# start=4.0s stop=4.5s SPEAKER_02
# start=4.5s stop=4.5s SPEAKER_01
# start=5.4s stop=6.4s SPEAKER_02
# start=7.5s stop=8.1s SPEAKER_02
# start=9.0s stop=12.9s SPEAKER_02
# start=17.8s stop=51.5s SPEAKER_01
# start=51.9s stop=55.6s SPEAKER_01
# start=56.3s stop=57.7s SPEAKER_01
# start=58.7s stop=58.7s SPEAKER_01
# start=58.7s stop=92.0s SPEAKER_02
# start=92.0s stop=105.8s SPEAKER_01
# start=106.8s stop=107.0s SPEAKER_01
# start=107.0s stop=115.1s SPEAKER_02
# start=115.9s stop=123.6s SPEAKER_02
# start=124.8s stop=140.3s SPEAKER_02
# start=133.3s stop=133.8s SPEAKER_00
# start=133.8s stop=134.0s SPEAKER_03
# start=134.0s stop=134.3s SPEAKER_00
# start=140.6s stop=160.1s SPEAKER_02
# start=160.3s stop=163.7s SPEAKER_02
# start=164.5s stop=165.8s SPEAKER_02
# start=166.2s stop=169.6s SPEAKER_02
# start=169.9s stop=188.0s SPEAKER_02
# start=188.6s stop=204.4s SPEAKER_02
# start=204.7s stop=226.6s SPEAKER_02
# start=226.8s stop=237.4s SPEAKER_01
# start=237.9s stop=243.0s SPEAKER_02
# start=243.4s stop=248.0s SPEAKER_02
# start=248.1s stop=249.0s SPEAKER_02
# start=250.2s stop=260.0s SPEAKER_02
# start=260.2s stop=282.4s SPEAKER_02
# start=283.4s stop=302.0s SPEAKER_02
# start=297.1s stop=297.6s SPEAKER_03
# start=298.4s stop=298.8s SPEAKER_01
# start=3713.2s stop=3713.2s SPEAKER_01
# start=3713.2s stop=3714.0s SPEAKER_02
# start=3714.0s stop=3724.7s SPEAKER_01
# start=3725.6s stop=3726.0s SPEAKER_01
# start=3726.0s stop=3735.1s SPEAKER_02
# start=3735.6s stop=3739.3s SPEAKER_02
# start=3740.5s stop=3744.0s SPEAKER_02
# start=3744.7s stop=3748.4s SPEAKER_02
# start=3749.0s stop=3749.3s SPEAKER_02
# start=3750.0s stop=3751.1s SPEAKER_02
# start=3751.1s stop=3751.1s SPEAKER_01
# start=3751.1s stop=3751.6s SPEAKER_02
# start=3752.1s stop=3758.3s SPEAKER_01
# start=3759.1s stop=3760.1s SPEAKER_01
# start=3760.7s stop=3761.6s SPEAKER_02
# start=3762.2s stop=3762.3s SPEAKER_01
# start=3762.3s stop=3762.6s SPEAKER_02
# start=3765.2s stop=3766.4s SPEAKER_02
# start=3767.0s stop=3768.4s SPEAKER_02
# start=3768.9s stop=3773.3s SPEAKER_02
# start=3773.8s stop=3786.3s SPEAKER_02
# start=3786.5s stop=3788.8s SPEAKER_02
# start=3788.8s stop=3788.9s SPEAKER_01
# start=3788.9s stop=3789.0s SPEAKER_02
# start=3789.0s stop=3789.1s SPEAKER_01
# start=3789.1s stop=3789.1s SPEAKER_02

# %%
# Saving the speakers and timestamps into a file
from datetime import timedelta

# Time formatting: seconds -> hh:mm:ss
def format_time(seconds):
    return str(timedelta(seconds=round(seconds)))

# Filename for the output
speaker_file = "formatted_timestamps.txt"

# Minimum duration for a speach in seconds
min_duration = 1.0

# Maximum permitted break between two segments of the same speaker
max_pause = 1.0

with open(speaker_file, "w", encoding="utf-8") as file:
    merged_start = None
    merged_end = None
    merged_speaker = None

    # Iterating over the segments
    for turn, _, speaker in diarization.itertracks(yield_label=True):
        # Calculation of the duration
        exact_duration = turn.end - turn.start
        duration = round(exact_duration, 2)

        # Only consider segments that are larger than the threshold
        if duration >= min_duration:
            # If the current speaker is the same as the previous one and the break is short enough
            if speaker == merged_speaker and (turn.start - merged_end) <= max_pause:
                # Update end time
                merged_end = turn.end
            else:
                # If there was previously a merged segment, write this segment
                if merged_speaker:
                    merged_exact_duration = merged_end - merged_start
                    start_hhmmss = format_time(merged_start)
                    end_hhmmss = format_time(merged_end)
                    file.write(f"Start: {start_hhmmss}, Dauer: {round(merged_exact_duration, 2)}s, Ende: {end_hhmmss}, Sprecher: {merged_speaker}\n")

                # Start new segment
                merged_start = turn.start
                merged_end = turn.end
                merged_speaker = speaker

    # Write last merged segment, if present
    if merged_speaker:
        merged_exact_duration = merged_end - merged_start
        start_hhmmss = format_time(merged_start)
        end_hhmmss = format_time(merged_end)
        file.write(f"Start: {start_hhmmss}, Dauer: {round(merged_exact_duration, 2)}s, Ende: {end_hhmmss}, Sprecher: {merged_speaker}\n")

# %%
# Assignment of speakers to their names
speaker_names = {

    'SPEAKER_01': 'Moderator',
    'SPEAKER_02': 'Robert Habeck (Grüne)',

}

with open(speaker_file, 'r') as f:
    lines = f.readlines()

# Add names to the file
new_lines = []
for line in lines:
    for speaker, speaker_name in speaker_names.items():
        if speaker in line:
            line = line.strip() + f', {speaker_name}\n'
            break 
    new_lines.append(line)

# Save changes directly in the original file
with open(speaker_file, 'w') as f:
    f.writelines(new_lines)

# %%
chunk_length_ms = 10 * 60 * 1000  # 10 min in milliseconds
audio = AudioSegment.from_wav(wav_filename)
chunks = [audio[i:i + chunk_length_ms] for i in range(0, len(audio), chunk_length_ms)]
final_transcript = []
offset = 0

# %%
import whisper_timestamped as whisper
model = model = whisper.load_model("medium")

# %%
for idx, chunk in enumerate(chunks):
    # Export the chunk to a temporary WAV file
    chunk_filename = f"chunk_{idx}.wav"
    chunk.export(chunk_filename, format="wav")
    
    # Transcribe the chunk
    result = whisper.transcribe(model, chunk_filename, temperature=0.2)
    
    # Adjust timestamps based on chunk start time
    for segment in result["segments"]:
        segment["start"] += offset
        segment["end"] += offset
        for word in segment.get("words", []):
            word["start"] += offset
            word["end"] += offset

    final_transcript.extend(result["segments"])
    
    # Update offset for next chunk
    offset += chunk_length_ms / 1000  # Convert ms to seconds
# Out:
# Detected language: German
# 100%|██████████| 60000/60000 [17:42<00:00, 56.48frames/s]
# Detected language: German
# 100%|██████████| 60000/60000 [16:05<00:00, 62.12frames/s]
# Detected language: German
# 100%|██████████| 60000/60000 [14:08<00:00, 70.72frames/s]
# Detected language: German
# 100%|██████████| 60000/60000 [15:52<00:00, 63.01frames/s]
# Detected language: German
# 100%|██████████| 60000/60000 [13:26<00:00, 74.37frames/s]
# Detected language: German
# 100%|██████████| 60000/60000 [12:00<00:00, 83.29frames/s]
# Detected language: German
# 100%|██████████| 19692/19692 [03:42<00:00, 88.41frames/s]

# %%
for segment in final_transcript:
    for word in segment.get("words", []):  # Use .get() to avoid errors if "words" is missing
        print(f"{word['start']:.2f}s - {word['end']:.2f}s: {word['text']}")
# Out:
# 0.16s - 0.42s: Wenn
# 0.42s - 0.76s: die
# 0.76s - 1.22s: FDP
# 1.22s - 1.56s: am
# 1.56s - 2.04s: Sonntag
# 2.04s - 2.22s: an
# 2.22s - 2.46s: der
# 2.46s - 3.60s: 5-Prozent-Hürde
# 3.60s - 4.06s: scheitern
# 4.06s - 4.36s: sollte
# 4.36s - 4.44s: ...
# 5.40s - 5.42s: ...
# 5.42s - 5.60s: hat
# 5.60s - 5.78s: sie
# 5.78s - 6.02s: selbst
# 6.02s - 6.26s: Schuld.
# 7.44s - 7.64s: Wären
# 7.64s - 7.80s: Sie
# 7.80s - 8.22s: traurig?
# 9.04s - 9.82s: Ich
# 9.82s - 9.98s: hab
# 9.98s - 10.18s: keine
# 10.18s - 10.60s: Emotionen
# 10.60s - 10.74s: zur
# 10.74s - 11.06s: FDP.
# 11.42s - 11.62s: Aber
# 11.62s - 11.80s: das
# 11.80s - 11.94s: ist
# 11.94s - 12.10s: hart
# 12.10s - 12.34s: selbst
# 12.34s - 12.90s: erarbeitet.
# 17.82s - 18.32s: Als
# 18.32s - 19.12s: Superminister
# 19.12s - 19.56s: wollte
# 19.56s - 19.80s: er
# 19.80s - 19.96s: das
# 19.96s - 20.24s: grüne
# 20.24s - 21.04s: Wirtschaftswunder
# 21.04s - 21.62s: einläuten.
# 21.70s - 21.98s: Doch
# 21.98s - 22.20s: statt
# 22.20s - 22.38s: dem
# 22.38s - 23.04s: Wunder
# 23.04s - 23.36s: kam
# 23.36s - 23.78s: die
# 23.78s - 24.32s: Rezession.
# 24.44s - 25.24s: Wirtschaftsminister
# 25.24s - 25.48s: will
# 25.48s - 25.72s: er
# 25.72s - 26.06s: trotzdem
# 26.06s - 26.42s: bleiben.
# 26.76s - 27.10s: Sollte
# 27.10s - 27.24s: das
# 27.24s - 27.42s: mit
# 27.42s - 27.64s: der
# 27.64s - 28.14s: Kanzlerschaft
# 28.14s - 28.38s: nicht
# 28.38s - 28.66s: klappen.
# 29.08s - 29.52s: Welche
# 29.52s - 30.52s: Perspektive
# 30.52s - 30.84s: sieht
# 30.84s - 31.04s: er
# 31.04s - 31.18s: für
# 31.18s - 31.38s: die
# 31.38s - 31.72s: Grünen
# 31.72s - 31.96s: und
# 31.96s - 32.14s: für
# 32.14s - 32.38s: sich?
# 32.48s - 32.96s: Herzlich
# 32.96s - 33.36s: willkommen
# 33.36s - 33.86s: dem
# 33.86s - 34.74s: Kanzlerkandidaten
# 34.74s - 34.88s: der
# 34.88s - 35.24s: Grünen,
# 35.26s - 35.58s: Robert
# 35.58s - 35.84s: Habeck.
# 35.92s - 36.10s: Hallo,
# 36.16s - 36.28s: Herr
# 36.28s - 36.70s: Fehmkirchen.
# 37.16s - 37.32s: Wir
# 37.32s - 37.68s: reden
# 37.68s - 38.02s: an
# 38.02s - 38.34s: einem,
# 38.34s - 38.94s: viele
# 38.94s - 39.44s: bezeichnen
# 39.44s - 39.62s: es
# 39.62s - 39.84s: jetzt
# 39.84s - 40.00s: schon,
# 40.06s - 40.76s: historischen
# 40.76s - 40.84s: Tag.
# 40.84s - 41.40s: In
# 41.40s - 42.70s: Saudi-Arabien
# 42.70s - 43.28s: kommen
# 43.28s - 43.96s: Vertreter
# 43.96s - 44.42s: Russlands,
# 44.52s - 44.66s: der
# 44.66s - 45.06s: russische
# 45.06s - 45.70s: Außenminister
# 45.70s - 45.98s: und
# 45.98s - 46.14s: der
# 46.14s - 46.74s: amerikanische
# 46.74s - 47.48s: Außenminister,
# 47.86s - 48.16s: zu
# 48.16s - 48.72s: Gesprächen
# 48.72s - 48.96s: über
# 48.96s - 49.22s: die
# 49.22s - 49.54s: Zukunft
# 49.54s - 49.80s: der
# 49.80s - 50.36s: Ukraine
# 50.36s - 51.32s: zusammen.
# 52.04s - 52.30s: Diese
# 52.30s - 52.96s: Verschiebung,
# 52.96s - 53.10s: die
# 53.10s - 53.30s: sich
# 53.30s - 53.68s: dort
# 53.68s - 54.14s: andeutet
# 54.14s - 54.34s: auf
# 54.34s - 54.66s: der
# 54.66s - 55.20s: internationalen
# 55.20s - 55.72s: Bühne,
# 56.32s - 56.48s: wie
# 56.48s - 56.66s: viel
# 56.66s - 56.94s: Sorge
# 56.94s - 57.30s: bereitet
# 57.30s - 57.44s: die
# 57.44s - 57.62s: Ihnen?
# 58.78s - 59.18s: Ja,
# 59.24s - 59.44s: schon
# 59.44s - 59.74s: sehr
# 59.74s - 59.98s: große
# 59.98s - 60.36s: Sorgen.
# 60.40s - 60.94s: Denn
# 60.94s - 61.02s: hier
# 61.02s - 61.20s: wird
# 61.20s - 61.46s: über
# 61.46s - 61.68s: die
# 61.68s - 62.04s: Köpfe
# 62.04s - 62.24s: der
# 62.24s - 62.60s: Ukraine
# 62.60s - 63.30s: hinweg
# 63.30s - 63.60s: gesprochen.
# 63.64s - 63.82s: Sie
# 63.82s - 64.16s: sind
# 64.16s - 64.42s: nicht
# 64.42s - 64.72s: dabei.
# 64.92s - 65.28s: Präsident
# 65.28s - 65.78s: Silensky
# 65.78s - 65.88s: hat
# 65.88s - 66.14s: sogar
# 66.14s - 66.50s: gesagt,
# 66.66s - 66.68s: er
# 66.68s - 66.86s: findet
# 66.86s - 67.08s: das
# 67.08s - 67.28s: nicht
# 67.28s - 67.76s: zielführend.
# 67.76s - 68.00s: Das
# 68.00s - 68.02s: ist,
# 68.02s - 68.16s: glaube
# 68.16s - 68.26s: ich,
# 68.38s - 68.46s: das
# 68.46s - 68.92s: Zitat.
# 69.76s - 69.92s: Also
# 69.92s - 70.04s: nicht
# 70.04s - 70.20s: nur
# 70.20s - 70.34s: sie
# 70.34s - 70.48s: sind
# 70.48s - 70.66s: nicht
# 70.66s - 70.91s: dabei,
# 70.91s - 71.24s: sondern
# 71.24s - 71.36s: sie
# 71.36s - 71.52s: sind
# 71.52s - 71.94s: offensichtlich
# 71.94s - 72.26s: nicht
# 72.26s - 72.48s: stark
# 72.48s - 72.76s: genug
# 72.76s - 73.34s: eingebunden.
# 74.10s - 74.98s: Also,
# 75.02s - 75.40s: Mächte
# 75.40s - 75.70s: teilen
# 75.70s - 75.88s: die
# 75.88s - 76.08s: Welt
# 76.08s - 76.36s: unter
# 76.36s - 76.58s: sich
# 76.58s - 76.88s: auf.
# 77.14s - 77.60s: Oder
# 77.60s - 77.94s: versuchen,
# 78.34s - 78.54s: eine
# 78.54s - 79.36s: Friedensordnung
# 79.54s - 79.90s: wahrscheinlich
# 79.90s - 80.10s: dann
# 80.10s - 80.20s: zu
# 80.20s - 80.50s: ihren
# 80.50s - 81.00s: Gunsten
# 81.00s - 81.66s: hinzubekommen.
# 81.66s - 81.86s: Das
# 81.86s - 82.00s: ist
# 82.00s - 82.20s: schon
# 82.20s - 82.40s: sehr
# 82.40s - 83.02s: bedrohlich.
# 83.46s - 84.16s: Und
# 84.16s - 84.34s: die
# 84.34s - 84.64s: Botschaft
# 84.64s - 84.84s: ist
# 84.84s - 85.00s: ja
# 85.00s - 85.14s: klar,
# 85.18s - 85.58s: Europa
# 85.58s - 86.10s: muss
# 86.10s - 86.54s: jetzt
# 86.54s - 86.76s: sein
# 86.76s - 87.06s: eigenes
# 87.06s - 87.26s: Ding
# 87.26s - 87.56s: machen.
# 87.82s - 88.04s: Aber
# 88.04s - 88.18s: das
# 88.18s - 88.36s: ist
# 88.36s - 88.64s: eben
# 88.64s - 88.78s: mehr
# 88.78s - 89.04s: als
# 89.04s - 89.24s: nur
# 89.24s - 89.54s: darüber
# 89.54s - 89.74s: zu
# 89.74s - 89.92s: reden.
# 89.92s - 90.12s: Das
# 90.12s - 90.26s: muss
# 90.26s - 90.40s: auch
# 90.40s - 90.52s: mal
# 90.52s - 90.86s: gemacht
# 90.86s - 91.24s: werden.
# 91.70s - 91.94s: Und
# 91.94s - 92.04s: das
# 92.04s - 92.18s: ist
# 92.18s - 92.32s: ja
# 92.32s - 92.80s: weitgehend.
# 93.22s - 93.56s: Warum
# 93.56s - 94.46s: wirkt
# 94.46s - 95.12s: Europa
# 95.12s - 95.72s: die
# 95.72s - 96.00s: Staats-
# 96.00s - 96.24s: und
# 96.24s - 96.94s: Regierungschefs
# 96.94s - 97.24s: in
# 97.24s - 97.74s: Europa
# 98.34s - 98.74s: so
# 98.74s - 99.20s: kalt
# 99.20s - 99.82s: erwischt?
# 100.02s - 100.30s: Dass
# 100.30s - 100.72s: Donald
# 100.72s - 101.16s: Trump
# 101.16s - 101.56s: eine
# 101.56s - 101.94s: andere
# 101.94s - 102.42s: Vorstellung
# 102.42s - 102.68s: von
# 102.68s - 102.92s: unserer
# 102.92s - 103.42s: Weltordnung
# 103.42s - 103.66s: hat,
# 104.02s - 104.54s: das
# 104.54s - 104.74s: hätte
# 104.74s - 104.96s: man
# 104.96s - 105.08s: ja
# 105.08s - 105.42s: durchaus
# 105.42s - 105.80s: erahnen
# 105.80s - 106.00s: können.
# 106.90s - 107.12s: Genau,
# 107.18s - 107.28s: das
# 107.28s - 107.42s: kann
# 107.42s - 107.80s: jemanden
# 107.80s - 108.16s: überraschen.
# 108.18s - 108.40s: Und
# 108.40s - 108.54s: auch
# 108.54s - 108.62s: die
# 108.62s - 108.84s: Rede
# 108.84s - 109.08s: von
# 109.08s - 109.40s: Europa
# 109.40s - 109.58s: muss
# 109.58s - 109.72s: sich
# 109.72s - 109.84s: auf
# 109.84s - 110.04s: seinen
# 110.04s - 110.28s: eigenen
# 110.28s - 110.72s: Stärken
# 110.72s - 111.07s: besinnen
# 111.07s - 111.36s: ist
# 111.36s - 111.64s: jetzt
# 111.64s - 111.78s: schon
# 111.78s - 112.04s: häufig
# 112.04s - 112.30s: genug
# 112.30s - 112.66s: gehalten
# 112.66s - 113.04s: worden.
# 113.36s - 113.56s: Im
# 113.56s - 113.84s: Grunde
# 113.84s - 114.00s: kann
# 114.00s - 114.16s: man
# 114.16s - 114.66s: dieses
# 114.66s - 115.00s: ...
# 116.02s - 116.22s: Das
# 116.22s - 116.34s: ist
# 116.34s - 116.46s: die
# 116.46s - 117.44s: Wake-up-Call-Geräte
# 117.44s - 117.60s: nicht
# 117.60s - 117.78s: mehr
# 117.78s - 118.30s: ertragen.
# 118.30s - 118.50s: Da
# 118.50s - 118.62s: hatten
# 118.62s - 118.76s: wir
# 118.76s - 119.38s: schon
# 119.38s - 119.90s: x-fach
# 119.90s - 120.18s: von.
# 120.68s - 120.84s: Ich
# 120.84s - 121.02s: denke,
# 121.14s - 121.16s: es
# 121.16s - 121.74s: gibt
# 121.74s - 122.14s: zwei
# 122.14s - 122.50s: Gründe,
# 122.64s - 122.82s: warum
# 122.82s - 123.28s: Europa
# 123.28s - 123.46s: ...
# 124.82s - 125.06s: viel
# 125.06s - 125.36s: darüber
# 125.36s - 125.80s: redet,
# 125.92s - 126.00s: zu
# 126.00s - 126.24s: eigener
# 126.24s - 126.42s: Kraft
# 126.42s - 126.94s: zu
# 126.94s - 127.22s: finden,
# 127.28s - 127.54s: aber
# 127.54s - 127.66s: ist
# 127.66s - 127.84s: noch
# 127.84s - 128.02s: nicht
# 128.02s - 128.16s: zu
# 128.16s - 128.48s: umsetzen.
# 128.48s - 128.72s: Das
# 128.72s - 129.00s: Erste
# 129.00s - 129.22s: ist,
# 129.32s - 129.42s: dass
# 129.42s - 129.92s: es
# 129.92s - 130.60s: gerade
# 130.60s - 130.84s: ungefähr
# 130.84s - 130.98s: so
# 130.98s - 131.21s: Hälfte
# 131.21s - 131.36s: mit
# 131.36s - 131.52s: sich
# 131.52s - 131.78s: selbst
# 131.78s - 132.18s: beschäftigt
# 132.18s - 132.34s: ist.
# 132.38s - 132.74s: Deutschland
# 132.74s - 132.94s: ja
# 132.94s - 133.16s: auch.
# 133.34s - 133.82s: Ja,
# 133.82s - 133.98s: das
# 133.98s - 134.12s: riecht
# 134.12s - 134.28s: aus.
# 134.54s - 134.76s: Die
# 134.76s - 135.86s: Führungsländer
# 135.86s - 136.36s: Deutschland,
# 136.44s - 137.42s: Frankreich
# 137.42s - 137.80s: gucken
# 137.80s - 138.04s: nach
# 138.04s - 138.28s: innen,
# 138.28s - 138.64s: fallen
# 138.64s - 139.12s: quasi
# 139.12s - 139.46s: aus
# 139.46s - 139.68s: als
# 139.68s - 140.62s: wirklich
# 140.62s - 141.32s: energisch
# 141.32s - 141.44s: nach
# 141.44s - 141.92s: vorgehende
# 141.92s - 142.10s: Achse.
# 142.10s - 142.32s: Auch
# 142.32s - 142.48s: die
# 142.48s - 142.86s: Bundesregierung.
# 143.62s - 143.88s: Kann
# 143.88s - 144.04s: ja
# 144.04s - 144.44s: keine
# 144.44s - 145.36s: finanziellen
# 145.36s - 145.92s: Zusagen
# 145.92s - 146.12s: machen,
# 146.22s - 146.42s: weil
# 146.42s - 146.60s: die
# 146.60s - 146.98s: Bundesregierung
# 146.98s - 147.24s: keine
# 147.24s - 147.52s: Mehrheit
# 147.52s - 147.62s: hat.
# 147.62s - 147.78s: Wir
# 147.78s - 147.90s: haben
# 147.90s - 148.10s: keinen
# 148.10s - 148.40s: Haushalt
# 148.40s - 149.04s: verabschiedet.
# 149.62s - 149.90s: Das
# 149.90s - 150.18s: Gleiche
# 150.18s - 150.34s: gilt
# 150.34s - 150.50s: für
# 150.50s - 150.90s: Österreich
# 150.90s - 151.58s: bekanntermaßen,
# 151.90s - 151.92s: die
# 151.92s - 152.24s: taumeln
# 152.24s - 152.50s: auch
# 152.50s - 152.80s: rum.
# 153.10s - 153.66s: Die
# 153.66s - 154.14s: niederländische
# 154.14s - 154.80s: Regierung
# 154.80s - 155.46s: ist
# 155.46s - 156.14s: Schwachbelgin,
# 156.26s - 156.54s: sucht
# 156.54s - 156.62s: eine
# 156.62s - 156.98s: Regierung.
# 158.24s - 158.40s: Also
# 158.40s - 159.14s: Zentraleuropa
# 159.14s - 159.34s: ist
# 159.34s - 159.54s: da
# 159.54s - 160.14s: gerade
# 160.14s - 160.72s: nach
# 160.72s - 161.62s: innen
# 161.62s - 162.24s: orientiert.
# 162.72s - 163.22s: Und
# 163.22s - 164.18s: zweitens,
# 164.60s - 165.26s: jenseits
# 165.26s - 166.54s: des
# 166.54s - 167.02s: politischen
# 167.02s - 167.42s: Willens,
# 167.52s - 167.64s: es
# 167.64s - 167.82s: gibt
# 167.82s - 168.06s: auch
# 168.06s - 168.28s: eine
# 168.28s - 168.90s: institutionelle
# 168.90s - 169.22s: Schwäche.
# 170.14s - 170.36s: Der
# 170.36s - 170.74s: Rat,
# 171.18s - 171.50s: also
# 171.50s - 171.70s: das
# 171.70s - 171.92s: Treffen
# 171.92s - 172.14s: der
# 172.14s - 172.48s: Staats-
# 172.48s - 172.50s: und
# 172.50s - 172.98s: Regierungschefs,
# 173.50s - 173.54s: ist
# 173.54s - 173.62s: in
# 173.62s - 173.86s: diesen
# 173.86s - 174.12s: Fragen
# 174.12s - 174.44s: immer
# 174.44s - 174.74s: auf
# 174.74s - 175.56s: Einstimmigkeit
# 175.56s - 176.04s: angewiesen.
# 176.10s - 176.40s: Manchmal
# 176.40s - 176.58s: gibt
# 176.58s - 177.24s: es
# 177.24s - 177.38s: so
# 177.38s - 177.62s: kleine
# 177.62s - 177.86s: Tricks,
# 177.94s - 178.06s: dass
# 178.06s - 178.22s: man
# 178.22s - 178.46s: Orban
# 178.46s - 178.74s: raus
# 178.74s - 178.93s: schickt
# 178.93s - 179.14s: und
# 179.14s - 179.34s: sagt,
# 179.42s - 179.52s: geh
# 179.52s - 180.04s: Kaffee
# 180.04s - 180.22s: trinken,
# 180.36s - 180.48s: dann
# 180.48s - 180.64s: stimmt
# 180.64s - 180.80s: man
# 180.80s - 180.96s: ab.
# 181.30s - 181.32s: Dann
# 181.32s - 181.34s: war
# 181.34s - 181.42s: er
# 181.42s - 181.58s: nicht
# 181.58s - 181.84s: dabei
# 181.84s - 182.00s: und
# 182.00s - 182.26s: konnte
# 182.26s - 182.44s: nicht
# 182.44s - 182.92s: sprechen.
# 183.86s - 183.88s: Aber
# 183.88s - 183.90s: das
# 183.90s - 184.14s: funktioniert
# 184.14s - 184.46s: nicht
# 184.46s - 184.62s: mehr.
# 185.42s - 185.44s: Deswegen
# 185.44s - 185.68s: muss
# 185.68s - 186.46s: Europa
# 186.46s - 188.92s: den
# 188.92s - 189.76s: institutionellen
# 189.76s - 190.28s: Zustand
# 190.28s - 190.82s: überwinden.
# 191.38s - 191.58s: Also
# 191.58s - 191.88s: hin
# 191.88s - 192.52s: zu
# 192.52s - 192.78s: einer
# 192.78s - 193.44s: echten
# 193.44s - 194.04s: föderalen
# 194.04s - 194.64s: Verfasstheit
# 194.64s - 194.82s: kommen.
# 194.82s - 195.08s: Das
# 195.08s - 195.30s: wird
# 195.30s - 195.52s: ein
# 195.52s - 195.74s: paar
# 195.74s - 196.06s: Jahre
# 196.06s - 196.46s: dauern.
# 197.02s - 197.32s: Aber
# 197.32s - 197.72s: den
# 197.72s - 198.14s: Anstoß
# 198.14s - 198.32s: muss
# 198.32s - 198.46s: man
# 198.46s - 198.61s: geben.
# 198.61s - 199.04s: Das
# 199.04s - 199.20s: ist
# 199.20s - 199.40s: wie
# 199.40s - 199.84s: Deutschland,
# 200.02s - 200.04s: der
# 200.04s - 200.92s: Kleinstarterei
# 200.92s - 203.28s: im
# 203.28s - 203.66s: 19.
# 203.72s - 204.18s: Jahrhundert.
# 204.80s - 205.08s: Und
# 205.08s - 206.18s: das
# 206.18s - 206.28s: ist
# 206.28s - 206.40s: nicht
# 206.40s - 206.60s: die
# 206.60s - 206.84s: Zukunft.
# 208.38s - 208.62s: Dass
# 208.62s - 208.90s: wir
# 208.90s - 209.56s: nicht
# 209.56s - 210.02s: über
# 210.02s - 210.56s: eine
# 210.56s - 211.20s: starke,
# 212.08s - 212.38s: auch
# 212.38s - 212.78s: demokratisch
# 212.78s - 213.60s: legitimitäre
# 213.60s - 214.28s: Verfasstheit,
# 214.34s - 214.56s: dann
# 214.56s - 214.80s: starke
# 214.80s - 215.22s: Entscheidungen
# 215.22s - 215.48s: treffen
# 215.48s - 215.78s: können,
# 216.34s - 216.56s: das
# 216.56s - 216.74s: wird
# 216.74s - 216.92s: am
# 216.92s - 217.30s: Ende
# 217.30s - 218.08s: Europa
# 218.08s - 218.26s: in
# 218.26s - 218.36s: die
# 218.36s - 218.68s: Handlungs-
# 218.68s - 218.70s: und
# 218.70s - 218.98s: Fähigkeit
# 218.98s - 219.22s: treiben.
# 219.38s - 219.86s: Klares
# 219.86s - 220.30s: Bekenntnis
# 220.30s - 220.50s: dafür,
# 220.52s - 220.66s: dass
# 220.66s - 220.84s: da
# 220.84s - 221.06s: weiter
# 221.06s - 221.48s: gearbeitet
# 221.48s - 221.66s: wird.
# 221.72s - 222.00s: Das
# 222.00s - 222.30s: bedeutet
# 222.30s - 222.76s: auch,
# 222.84s - 222.96s: dass
# 222.96s - 223.08s: die
# 223.08s - 223.32s: großen
# 223.32s - 224.12s: Mitgliedsländer
# 224.24s - 224.54s: diesen
# 224.54s - 224.76s: Weg
# 224.76s - 225.26s: einschlagen,
# 225.36s - 225.50s: vor
# 225.50s - 225.62s: allem
# 225.62s - 225.76s: die
# 225.76s - 225.98s: nächste
# 225.98s - 226.42s: Bundesregierung.
# 227.00s - 227.04s: Es
# 227.04s - 227.06s: ist
# 227.06s - 227.12s: so
# 227.12s - 227.54s: wichtiger,
# 227.74s - 228.00s: dass
# 228.00s - 228.20s: es
# 228.20s - 228.48s: bald
# 228.48s - 228.96s: eine
# 228.96s - 229.74s: handlungsfähige
# 229.74s - 230.32s: Bundesregierung
# 230.32s - 230.68s: gibt.
# 230.98s - 231.18s: Am
# 231.18s - 231.90s: Sonntag
# 231.90s - 232.16s: wird
# 232.16s - 232.60s: gewählt.
# 232.64s - 232.82s: Herr
# 232.82s - 233.46s: Habeck,
# 233.66s - 234.06s: wie
# 234.06s - 234.50s: groß
# 234.50s - 234.80s: sehen
# 234.80s - 235.06s: Sie
# 235.06s - 235.26s: Ihre
# 235.26s - 235.84s: Chancen,
# 235.84s - 236.04s: doch
# 236.04s - 236.30s: noch
# 236.30s - 236.94s: Bundeskanzler
# 236.94s - 237.06s: zu
# 237.06s - 237.28s: werden?
# 237.94s - 238.22s: Die
# 238.22s - 238.38s: sind
# 238.38s - 238.58s: jetzt
# 238.58s - 238.64s: nicht
# 238.64s - 238.96s: größer
# 238.96s - 239.36s: geworden.
# 239.46s - 239.66s: In
# 239.66s - 239.76s: den
# 239.76s - 240.04s: letzten
# 240.04s - 240.16s: drei,
# 240.16s - 240.36s: vier
# 240.36s - 240.66s: Wochen,
# 240.90s - 240.92s: sagen
# 240.92s - 241.04s: wir
# 241.04s - 241.22s: seit
# 241.22s - 241.36s: der
# 241.36s - 242.06s: Abstimmung
# 242.06s - 243.86s: von
# 243.86s - 244.16s: Friedrich
# 244.16s - 244.44s: Merz
# 244.44s - 244.62s: mit
# 244.62s - 244.84s: der
# 244.84s - 245.08s: AfD
# 245.14s - 245.36s: oder
# 245.36s - 245.48s: der
# 245.48s - 245.90s: Union
# 245.90s - 246.30s: und
# 246.30s - 246.72s: FDP
# 246.72s - 247.00s: mit
# 247.00s - 247.18s: der
# 247.18s - 247.48s: AfD,
# 250.40s - 250.70s: sehen
# 250.70s - 250.94s: wir
# 250.94s - 251.42s: eher
# 251.42s - 251.54s: so
# 251.54s - 251.64s: eine
# 251.64s - 251.88s: Art
# 251.88s - 252.66s: oppositionellen
# 252.66s - 253.08s: Reflex.
# 253.14s - 253.28s: Die
# 253.28s - 253.54s: Linke
# 253.54s - 253.70s: ist
# 253.70s - 254.20s: stärker
# 254.20s - 254.38s: geworden.
# 254.80s - 255.56s: Die
# 255.56s - 255.88s: Linke
# 255.88s - 255.90s: wird
# 255.90s - 256.24s: wieder
# 256.24s - 256.76s: reanimiert.
# 256.76s - 257.56s: Die
# 257.56s - 257.88s: war
# 257.88s - 258.08s: ja
# 258.08s - 258.32s: quasi
# 258.32s - 258.48s: schon
# 258.48s - 258.64s: raus
# 258.64s - 258.80s: aus
# 258.80s - 258.98s: dem
# 258.98s - 259.50s: Bundestag.
# 260.46s - 261.20s: Umgekehrt
# 261.20s - 261.40s: kann
# 261.40s - 261.54s: man
# 261.54s - 261.78s: daraus
# 261.78s - 262.02s: ja
# 262.02s - 262.28s: auch
# 262.28s - 263.22s: die
# 263.22s - 263.60s: Botschaft
# 263.60s - 264.12s: ableiten,
# 264.88s - 265.18s: dass
# 265.18s - 265.48s: man,
# 265.78s - 266.38s: ich
# 266.38s - 266.72s: finde
# 266.72s - 266.84s: das
# 266.84s - 267.02s: gut,
# 267.04s - 267.26s: dass
# 267.26s - 267.44s: die
# 267.44s - 268.06s: Linke
# 268.06s - 268.36s: im
# 268.36s - 268.88s: Bundestag
# 268.88s - 269.10s: jetzt
# 269.10s - 269.32s: wieder
# 269.32s - 269.70s: vertreten
# 269.70s - 269.90s: ist.
# 270.54s - 271.62s: Aber
# 271.62s - 271.74s: dass
# 271.74s - 272.00s: sie
# 272.00s - 272.76s: wahrscheinlich
# 272.76s - 273.24s: vertreten
# 273.24s - 273.50s: sein
# 273.50s - 273.84s: wird.
# 274.24s - 274.46s: Dass
# 274.46s - 274.80s: es
# 274.80s - 275.08s: jetzt
# 275.08s - 275.26s: aber
# 275.26s - 275.44s: darum
# 275.44s - 275.66s: geht,
# 275.74s - 275.92s: sie
# 275.92s - 276.16s: werden
# 276.16s - 276.36s: ja
# 276.36s - 276.60s: nicht
# 276.60s - 276.72s: in
# 276.72s - 276.88s: die
# 276.88s - 277.14s: Regierung
# 277.14s - 277.62s: eintreten.
# 278.28s - 278.38s: Sie
# 278.38s - 278.66s: beziehen
# 278.66s - 278.82s: sich,
# 278.98s - 279.20s: wollen
# 279.20s - 279.82s: Opposition
# 279.82s - 280.10s: sein,
# 280.40s - 280.66s: dass
# 280.66s - 281.14s: wir
# 281.14s - 281.66s: als
# 281.66s - 282.34s: Regierung
# 282.34s - 283.72s: oder
# 283.72s - 284.10s: in
# 284.10s - 284.28s: der
# 284.28s - 284.56s: Regierung
# 284.64s - 284.74s: oder
# 284.74s - 284.96s: in
# 284.96s - 285.44s: Verhandlung
# 285.44s - 285.60s: zu
# 285.60s - 285.72s: einer
# 285.72s - 286.06s: Regierung
# 286.06s - 286.30s: ein
# 286.30s - 286.68s: starkes
# 286.68s - 287.38s: Mandat
# 287.38s - 287.86s: für
# 287.86s - 288.56s: Klimaschutz,
# 288.76s - 289.02s: für
# 289.02s - 289.42s: Soziale
# 289.42s - 290.04s: Gerechtigkeit,
# 290.22s - 290.36s: für
# 290.36s - 290.76s: Europa,
# 291.24s - 291.64s: für
# 291.64s - 291.92s: eine
# 291.92s - 293.12s: moderne
# 293.12s - 293.32s: und
# 293.32s - 293.68s: progressive
# 293.68s - 294.08s: Politik
# 294.08s - 294.44s: bekommen.
# 294.68s - 294.88s: Und
# 294.88s - 295.06s: darum
# 295.06s - 295.28s: werden
# 295.28s - 295.38s: wir
# 295.38s - 295.68s: kämpfen
# 295.68s - 295.88s: in
# 295.88s - 295.98s: den
# 295.98s - 296.18s: nächsten
# 296.18s - 296.42s: Tagen
# 296.42s - 296.58s: und
# 296.58s - 296.80s: Wochen.
# 297.10s - 297.66s: Wochen
# 297.66s - 297.80s: sind
# 297.80s - 297.88s: es
# 297.88s - 298.04s: nicht
# 298.04s - 298.20s: mehr,
# 298.24s - 298.48s: Tage
# 298.48s - 298.94s: nur
# 298.94s - 299.01s: noch.
# 299.01s - 299.03s: Nur
# 299.03s - 299.06s: noch
# 299.06s - 299.28s: Tage.
# 299.94s - 299.96s: Es
# 299.96s - 299.98s: ist
# 299.98s - 300.00s: so
# 300.00s - 300.30s: eingeübt
# 300.30s - 300.64s: in
# 300.64s - 300.80s: den
# 300.80s - 301.06s: nächsten
# 301.06s - 301.34s: Wochen.
# 301.98s - 302.00s: Aber
# 302.00s - 302.02s: jetzt
# 302.02s - 302.16s: sind
# 302.16s - 302.24s: es
# 302.24s - 302.34s: nur
# 302.34s - 302.54s: noch
# 302.54s - 302.74s: Tage,
# 302.78s - 303.00s: eher
# 303.00s - 303.26s: Stunden.
# 304.02s - 304.04s: Olaf
# 304.04s - 304.22s: Scholz
# 304.22s - 304.42s: war
# 304.42s - 304.84s: vergangene
# 304.84s - 305.12s: Woche
# 305.12s - 305.50s: hier.
# 305.86s - 306.04s: Er
# 306.04s - 306.22s: hat
# 306.22s - 306.42s: auf
# 306.42s - 306.64s: meine
# 306.64s - 306.96s: Frage
# 306.96s - 307.22s: gesagt,
# 307.34s - 307.36s: er
# 307.36s - 307.60s: würde
# 307.60s - 307.84s: seine
# 307.84s - 308.16s: Chancen,
# 308.18s - 308.74s: Bundeskanzler
# 308.74s - 308.84s: zu
# 308.84s - 309.02s: werden,
# 309.42s - 309.56s: bei
# 309.56s - 309.92s: 60
# 309.92s - 310.38s: Prozent
# 310.38s - 310.64s: sehen.
# 310.98s - 311.36s: Jetzt
# 311.36s - 311.60s: lassen
# 311.60s - 311.72s: Sie
# 311.72s - 311.90s: uns
# 311.90s - 312.22s: mal
# 312.22s - 313.46s: in
# 313.46s - 313.68s: die
# 313.68s - 314.34s: Gedankenwelt
# 314.36s - 314.76s: eines
# 314.76s - 316.04s: Wahlkämpfers
# 316.04s - 316.40s: schauen.
# 316.64s - 316.98s: Glaubt
# 316.98s - 317.12s: ihr
# 317.12s - 317.36s: das
# 317.36s - 317.74s: wirklich?
# 317.88s - 318.18s: Braucht
# 318.18s - 318.34s: man
# 318.34s - 318.60s: diese
# 318.60s - 319.56s: Selbstsuggestion,
# 319.58s - 319.78s: um
# 319.78s - 319.94s: bis
# 319.94s - 320.16s: zum
# 320.16s - 320.36s: Schluss
# 320.36s - 321.06s: durchzuhalten?
# 321.98s - 322.30s: Also
# 322.30s - 322.42s: ich
# 322.42s - 322.60s: brauch
# 322.60s - 322.70s: sie
# 322.70s - 322.92s: nicht.
# 323.66s - 324.04s: Das
# 324.04s - 324.24s: war
# 324.24s - 324.62s: ja
# 324.62s - 324.94s: nie
# 324.94s - 325.74s: eine
# 325.74s - 326.02s: große
# 326.02s - 326.82s: Wahrscheinlichkeit.
# 327.02s - 327.18s: Sie
# 327.18s - 327.32s: ist
# 327.32s - 327.46s: es
# 327.46s - 327.58s: nicht
# 327.58s - 327.76s: gerade
# 327.76s - 328.14s: größer
# 328.14s - 328.48s: geworden.
# 329.56s - 330.22s: Aber
# 330.22s - 331.36s: die
# 331.36s - 332.18s: Motivation,
# 332.46s - 332.50s: in
# 332.50s - 332.74s: dieser
# 332.74s - 332.94s: Zeit
# 332.94s - 333.12s: einen
# 333.12s - 333.40s: Unterschied
# 333.40s - 333.62s: zu
# 333.62s - 333.84s: machen,
# 334.18s - 334.50s: ein
# 334.50s - 334.92s: Angebot
# 334.92s - 335.08s: zu
# 335.08s - 335.24s: machen,
# 335.34s - 335.44s: dass
# 335.44s - 335.60s: es
# 335.60s - 335.64s: den
# 335.64s - 335.82s: Menschen
# 335.82s - 336.16s: Hoffnung
# 336.16s - 336.32s: gibt,
# 336.36s - 336.90s: Zuversicht,
# 336.92s - 337.06s: wie
# 337.06s - 337.20s: wir
# 337.20s - 337.70s: plakatiert
# 337.70s - 337.94s: haben,
# 338.22s - 338.40s: dass
# 338.40s - 338.56s: wir
# 338.56s - 338.74s: für
# 338.74s - 338.98s: die
# 338.98s - 339.36s: Themen
# 339.36s - 339.84s: kämpfen
# 339.84s - 340.06s: und
# 340.06s - 340.26s: stehen,
# 341.28s - 341.48s: die
# 341.48s - 342.54s: wir
# 342.54s - 343.72s: identifiziert
# 343.72s - 343.97s: haben,
# 343.97s - 344.16s: als
# 344.16s - 344.34s: die
# 344.34s - 344.84s: Zukunftsthemen.
# 344.84s - 345.06s: Die
# 345.06s - 345.22s: ist
# 345.22s - 345.36s: ja
# 345.36s - 345.58s: völlig
# 345.58s - 346.14s: ungebrochen.
# 346.24s - 346.48s: Wir
# 346.48s - 346.76s: haben
# 346.76s - 347.10s: gesehen,
# 347.36s - 347.38s: auch
# 347.38s - 347.46s: in
# 347.46s - 347.64s: den
# 347.64s - 347.96s: Daten,
# 348.04s - 348.06s: die
# 348.06s - 348.22s: wir
# 348.22s - 348.54s: haben,
# 348.88s - 349.12s: dass
# 349.12s - 349.26s: wir
# 349.26s - 349.76s: Vertrauen
# 349.76s - 350.26s: zurückgewonnen
# 350.26s - 350.44s: haben.
# 350.52s - 350.56s: Wir
# 350.56s - 350.76s: sehen
# 350.76s - 350.94s: es
# 350.94s - 351.28s: überall,
# 351.36s - 351.56s: unsere
# 351.56s - 352.08s: Veranstaltungen
# 352.08s - 352.34s: platzen
# 352.34s - 352.54s: aus
# 352.54s - 352.72s: allen
# 352.72s - 352.93s: Nähten.
# 352.93s - 353.06s: Wir
# 353.06s - 353.24s: haben
# 353.24s - 353.46s: eine
# 353.46s - 354.02s: Eintrittswelle
# 354.02s - 354.12s: wie
# 354.12s - 354.30s: noch
# 354.30s - 354.44s: nie
# 354.44s - 354.52s: in
# 354.52s - 354.76s: unserer
# 354.76s - 355.54s: Parteigeschichte.
# 357.36s - 357.38s: Und
# 357.38s - 357.40s: auch,
# 357.52s - 357.98s: dass
# 357.98s - 358.12s: die
# 358.12s - 358.36s: Leute,
# 358.36s - 358.50s: die
# 358.50s - 358.74s: sich
# 358.74s - 359.06s: vorstellen
# 359.06s - 359.28s: können,
# 359.28s - 359.46s: die
# 359.46s - 359.70s: Grünen
# 359.70s - 359.86s: zu
# 359.86s - 360.02s: wählen,
# 360.14s - 360.18s: sich
# 360.18s - 361.00s: wieder
# 361.00s - 361.42s: deutlich
# 361.42s - 361.82s: drastisch
# 361.82s - 362.22s: gewachsen.
# 362.60s - 362.88s: Jetzt
# 362.88s - 363.06s: müssen
# 363.06s - 363.18s: wir
# 363.18s - 363.26s: es
# 363.26s - 363.48s: halt
# 363.48s - 363.88s: einlösen.
# 364.60s - 364.78s: Es
# 364.78s - 364.94s: gibt
# 364.94s - 365.10s: jetzt
# 365.10s - 365.30s: gar
# 365.30s - 365.46s: keinen
# 365.46s - 365.82s: Grund,
# 366.40s - 366.70s: die
# 366.70s - 366.94s: Ohren
# 366.94s - 367.20s: hängen
# 367.20s - 367.36s: zu
# 367.36s - 367.50s: lassen.
# 367.54s - 367.82s: Sondern
# 367.82s - 367.92s: im
# 367.92s - 368.64s: Gegenteil,
# 369.00s - 369.44s: wir
# 369.44s - 369.74s: sind
# 369.74s - 369.88s: alle
# 369.88s - 370.10s: ein
# 370.10s - 370.32s: bisschen
# 370.84s - 371.14s: durch
# 371.14s - 371.52s: diese
# 371.52s - 372.39s: Vorbereitungsmühlen,
# 372.39s - 372.62s: also
# 372.62s - 372.84s: wir,
# 373.00s - 373.18s: die
# 373.18s - 373.64s: professionellen
# 373.64s - 374.28s: Wahlkämpfer,
# 374.54s - 374.82s: so
# 374.82s - 375.00s: im
# 375.00s - 376.26s: Endsportmodus.
# 376.46s - 376.80s: Für
# 376.80s - 377.04s: viele
# 377.04s - 377.28s: Menschen
# 377.28s - 377.44s: geht
# 377.44s - 377.62s: es
# 377.62s - 377.66s: jetzt
# 377.66s - 377.78s: erst
# 377.78s - 377.94s: los.
# 378.02s - 378.44s: Jetzt
# 378.44s - 378.70s: sieht
# 378.70s - 378.88s: man,
# 379.00s - 379.12s: ach,
# 379.20s - 379.26s: guck
# 379.26s - 379.60s: mal,
# 380.08s - 380.28s: wie
# 380.28s - 380.42s: vor
# 380.42s - 380.56s: einer
# 380.56s - 380.80s: Reise.
# 380.80s - 381.00s: Jetzt
# 381.00s - 381.12s: musst
# 381.12s - 381.24s: du
# 381.24s - 381.32s: die
# 381.32s - 381.56s: Koffer
# 381.56s - 381.82s: packen.
# 382.34s - 383.00s: In
# 383.00s - 383.52s: drei
# 383.52s - 383.72s: Wochen
# 383.72s - 383.88s: geht
# 383.88s - 383.94s: es
# 383.94s - 384.08s: nach
# 384.08s - 384.52s: Mallorca.
# 384.82s - 385.06s: Und
# 385.06s - 385.40s: jetzt
# 385.40s - 385.60s: musst
# 385.60s - 385.72s: du
# 385.72s - 385.88s: sagen,
# 386.22s - 386.74s: ist
# 386.74s - 386.90s: mein
# 386.90s - 387.16s: Pass
# 387.16s - 387.42s: eigentlich
# 387.42s - 387.62s: noch
# 387.62s - 387.85s: da?
# 387.85s - 388.08s: Und
# 388.08s - 388.22s: ist
# 388.22s - 388.44s: ja
# 388.44s - 388.94s: abgelaufen.
# 389.78s - 390.02s: Das
# 390.02s - 390.16s: ist
# 390.16s - 390.68s: völlig
# 390.68s - 391.36s: ungleichzeitig.
# 391.42s - 391.60s: Und
# 391.60s - 392.04s: deswegen
# 392.04s - 392.56s: alle
# 392.56s - 393.26s: Mobilisierung,
# 393.36s - 393.56s: alle
# 393.56s - 393.84s: Kraft,
# 394.26s - 394.54s: jetzt
# 394.54s - 395.08s: auf
# 395.08s - 395.20s: die
# 395.20s - 395.42s: letzten
# 395.42s - 395.70s: Tage
# 395.70s - 396.08s: gelenkt.
# 396.22s - 396.58s: Dahinter
# 396.58s - 396.80s: steckt
# 396.80s - 396.98s: die
# 396.98s - 397.24s: Hoffnung,
# 397.34s - 397.44s: dass
# 397.44s - 397.56s: in
# 397.56s - 397.70s: den
# 397.70s - 397.92s: letzten
# 397.92s - 398.18s: Tagen
# 398.38s - 398.44s: auch
# 398.44s - 398.56s: für
# 398.56s - 398.72s: die
# 398.72s - 398.98s: Grünen
# 398.98s - 399.14s: noch
# 399.14s - 399.28s: was
# 399.28s - 399.48s: nach
# 399.48s - 399.62s: oben
# 399.62s - 399.88s: gehen
# 399.88s - 400.04s: kann?
# 402.28s - 402.36s: Und
# 402.36s - 402.68s: die
# 402.68s - 403.18s: uns
# 403.18s - 403.48s: eine
# 403.48s - 403.84s: gute
# 403.84s - 404.14s: Chance
# 404.14s - 404.38s: geben.
# 404.62s - 404.82s: Die
# 404.82s - 405.20s: Daten,
# 405.38s - 405.74s: zu
# 405.74s - 405.90s: denen
# 405.90s - 406.20s: ich
# 406.20s - 406.56s: Zugang
# 406.56s - 406.78s: hab,
# 406.90s - 407.08s: die
# 407.08s - 407.32s: sagen,
# 408.16s - 408.24s: dass
# 408.24s - 408.26s: im
# 408.26s - 408.68s: Laufe
# 408.68s - 409.06s: dieses
# 409.06s - 409.22s: doch
# 409.22s - 409.48s: sehr
# 409.48s - 409.74s: kurzen
# 409.74s - 410.65s: Winterwahlkampfes
# 410.65s - 410.80s: für
# 410.80s - 410.96s: die
# 410.96s - 411.16s: Grünen
# 411.16s - 411.42s: eigentlich
# 411.42s - 411.60s: gar
# 411.60s - 411.68s: nicht
# 411.68s - 411.88s: viel
# 411.88s - 412.20s: passiert
# 412.20s - 412.36s: ist.
# 412.82s - 412.84s: Die
# 412.84s - 412.86s: liegen
# 412.86s - 412.90s: in
# 412.90s - 413.02s: den
# 413.02s - 413.40s: Umfragen
# 413.40s - 413.68s: zwischen
# 413.68s - 414.18s: 13
# 414.18s - 414.68s: und
# 414.68s - 415.22s: 15
# 415.22s - 415.70s: Prozent.
# 416.10s - 416.62s: Und
# 416.62s - 416.80s: da
# 416.80s - 417.00s: ist
# 417.00s - 417.26s: ja
# 417.26s - 417.68s: offenbar
# 417.68s - 417.98s: bisher
# 417.98s - 418.32s: nicht
# 418.32s - 418.74s: gelungen,
# 419.44s - 419.74s: das
# 419.74s - 419.98s: zu
# 419.98s - 420.26s: schaffen,
# 420.42s - 420.70s: wonach
# 420.70s - 421.14s: jeder
# 421.14s - 421.62s: Wahlkampf
# 421.62s - 421.96s: agiert,
# 422.04s - 422.36s: worüber
# 422.36s - 422.64s: Sie
# 422.64s - 422.96s: auch
# 422.96s - 423.22s: sprechen,
# 423.30s - 423.50s: ein
# 423.50s - 424.16s: Momentum
# 424.16s - 424.38s: zu
# 424.38s - 424.62s: schaffen.
# 424.72s - 425.10s: Warum
# 425.10s - 425.36s: nicht?
# 426.08s - 426.52s: Ich
# 426.52s - 426.88s: würde
# 426.88s - 427.20s: sagen,
# 427.26s - 427.58s: wegen
# 427.58s - 427.98s: drei
# 427.98s - 428.08s: ...
# 429.46s - 430.08s: parallel,
# 430.22s - 430.28s: oder
# 430.28s - 430.38s: ist
# 430.38s - 430.58s: er
# 430.58s - 430.74s: eh
# 430.74s - 430.86s: nicht,
# 430.86s - 431.02s: in
# 431.02s - 431.64s: Anschlägen
# 431.64s - 431.88s: von
# 431.88s - 432.50s: Geflüchteten
# 432.50s - 432.92s: begangen,
# 433.10s - 433.62s: fürchterliche
# 433.62s - 434.10s: Attentate,
# 434.10s - 434.28s: die
# 434.28s - 434.54s: Menschen
# 434.54s - 435.10s: getötet
# 435.10s - 435.30s: haben.
# 435.34s - 435.70s: Und
# 435.70s - 435.86s: dadurch
# 435.86s - 436.08s: hat
# 436.08s - 436.84s: sich
# 436.84s - 437.78s: der,
# 437.78s - 438.30s: zu
# 438.30s - 438.64s: Recht,
# 438.64s - 438.88s: muss
# 438.88s - 439.04s: man
# 439.04s - 439.28s: sagen,
# 439.50s - 439.52s: ja,
# 440.36s - 440.70s: der
# 440.70s - 441.24s: politische
# 441.24s - 441.88s: Schwerpunkt
# 441.88s - 442.92s: nicht
# 442.92s - 443.40s: auf
# 443.40s - 443.98s: Europa
# 443.98s - 444.54s: Zukunft,
# 444.90s - 445.68s: Klima,
# 445.82s - 446.26s: Bildung,
# 446.46s - 446.86s: Zusammenhalt
# 446.86s - 447.04s: des
# 447.04s - 447.36s: Landes
# 447.36s - 447.82s: geschoben,
# 447.86s - 448.14s: sondern
# 448.14s - 448.34s: auf
# 448.34s - 448.56s: die
# 448.56s - 448.92s: Sicherheits-
# 448.92s - 449.04s: und
# 449.04s - 449.86s: Migrationsfragen.
# 450.26s - 450.46s: Und
# 450.46s - 450.60s: da
# 450.60s - 450.68s: ist
# 450.68s - 450.82s: es
# 450.82s - 451.12s: ja,
# 451.28s - 451.50s: das
# 451.50s - 451.62s: muss
# 451.62s - 451.74s: man
# 451.74s - 451.92s: ehrlich
# 451.92s - 452.12s: sagen,
# 452.12s - 453.04s: nicht
# 453.04s - 453.44s: Themen,
# 453.92s - 454.32s: wo
# 454.32s - 455.54s: wir
# 455.54s - 456.94s: automatisch
# 456.94s - 457.28s: das
# 457.28s - 457.52s: größte
# 457.52s - 457.94s: Vertrauen
# 457.94s - 458.10s: haben.
# 458.42s - 458.96s: Ich
# 458.96s - 459.20s: finde,
# 459.24s - 459.32s: da
# 459.32s - 459.46s: wird
# 459.46s - 459.74s: viel
# 459.74s - 459.81s: gesehen.
# 459.81s - 459.83s: Nicht
# 459.83s - 460.06s: die
# 460.06s - 460.38s: grüne
# 460.38s - 461.02s: Kernkompetenz.
# 461.42s - 461.82s: So
# 461.82s - 462.08s: würden
# 462.08s - 462.38s: das
# 462.38s - 462.54s: die
# 462.54s - 462.90s: Journalisten
# 462.90s - 463.42s: beschreiben,
# 463.68s - 463.76s: das
# 463.76s - 463.92s: stimmt
# 463.92s - 464.14s: aber
# 464.14s - 464.40s: nicht.
# 465.04s - 465.42s: Sicherheit
# 465.42s - 465.66s: ist
# 465.66s - 465.88s: eine
# 465.88s - 466.62s: Kernkompetenz
# 466.62s - 466.80s: von
# 466.80s - 467.00s: uns.
# 467.08s - 467.32s: Seit
# 467.32s - 467.66s: vielen
# 467.66s - 467.90s: Jahren
# 467.90s - 468.16s: machen
# 468.16s - 468.50s: Irene
# 468.50s - 468.88s: Mihalic
# 468.88s - 469.06s: und
# 469.06s - 469.46s: Konstantin
# 469.46s - 469.60s: von
# 469.60s - 469.84s: Notz
# 469.84s - 469.94s: und
# 469.94s - 470.24s: andere
# 470.24s - 470.86s: da
# 470.86s - 471.44s: hervorragende
# 471.44s - 471.66s: Arbeit.
# 471.70s - 472.46s: Integration
# 472.46s - 472.76s: stellen
# 472.76s - 473.00s: wir
# 473.00s - 473.26s: viele
# 473.26s - 473.90s: Ministerinnen
# 473.90s - 474.12s: auf
# 474.12s - 474.32s: der
# 474.32s - 474.84s: Landesebene.
# 475.16s - 475.42s: Also,
# 475.54s - 475.56s: da
# 475.56s - 475.84s: ist
# 475.84s - 476.08s: eine
# 476.08s - 476.64s: wirkliche
# 476.64s - 477.04s: Kompetenz
# 477.04s - 477.28s: da.
# 477.66s - 477.94s: Aber
# 477.94s - 478.12s: die
# 478.12s - 478.64s: Zuschreibung
# 478.64s - 478.78s: ist
# 478.78s - 479.12s: natürlich
# 479.12s - 479.36s: erst
# 479.36s - 480.12s: einmal
# 480.12s - 480.88s: eine
# 480.88s - 481.18s: etwas
# 481.18s - 481.60s: andere.
# 482.18s - 482.40s: Und
# 482.40s - 482.52s: so
# 482.52s - 482.92s: gesehen
# 482.92s - 483.14s: ist
# 483.14s - 483.28s: es
# 483.28s - 483.50s: erst
# 483.50s - 483.82s: mal
# 483.82s - 484.08s: eine
# 484.08s - 484.46s: Leistung,
# 484.46s - 484.60s: dass
# 484.60s - 484.98s: wir
# 484.98s - 485.74s: die
# 485.74s - 486.52s: Umfragewerte
# 486.52s - 486.74s: von
# 486.74s - 487.76s: Weihnachten
# 487.76s - 488.04s: über
# 488.04s - 488.14s: den
# 488.14s - 488.74s: Dominaum
# 488.94s - 489.32s: gehalten
# 489.32s - 489.62s: haben.
# 489.92s - 490.12s: Denn
# 490.12s - 490.24s: das
# 490.24s - 490.38s: hat
# 490.38s - 490.52s: es
# 490.52s - 490.64s: ja
# 490.64s - 490.80s: auch
# 490.80s - 490.94s: noch
# 490.94s - 491.16s: nicht
# 491.16s - 491.48s: wirklich
# 491.48s - 491.82s: gegeben,
# 492.72s - 492.90s: dass
# 492.90s - 493.02s: in
# 493.02s - 493.26s: einem
# 493.26s - 493.84s: Wahlkampf
# 493.84s - 494.24s: drei
# 494.24s - 494.84s: solche
# 494.84s - 495.50s: perversen
# 495.50s - 495.60s: und
# 495.60s - 496.04s: brutalen
# 496.04s - 496.24s: Mote
# 496.26s - 496.42s: so
# 496.42s - 496.62s: kurz
# 496.62s - 497.20s: hintereinander
# 497.20s - 497.48s: kommen.
# 497.98s - 498.60s: Also,
# 499.04s - 499.10s: das
# 499.10s - 499.38s: ist
# 499.38s - 500.12s: eine
# 500.12s - 500.32s: der
# 500.32s - 500.58s: Gründe.
# 500.68s - 500.78s: Und
# 500.78s - 500.90s: dann
# 500.90s - 501.08s: habe
# 501.08s - 501.18s: ich
# 501.18s - 501.28s: es
# 501.28s - 501.50s: schon
# 501.50s - 501.74s: gesagt,
# 501.82s - 502.02s: das
# 502.02s - 503.72s: Abstimmungsverhalten
# 503.72s - 504.66s: von
# 504.66s - 504.98s: Friedrich
# 504.98s - 505.14s: im
# 505.14s - 505.32s: Herzen
# 505.32s - 505.48s: mit
# 505.48s - 505.66s: der
# 505.66s - 505.94s: AfD
# 506.02s - 506.38s: hat
# 506.38s - 506.68s: zu
# 506.68s - 507.10s: einem
# 507.10s - 507.56s: Reflex
# 507.56s - 507.92s: geführt
# 507.92s - 508.12s: bei
# 508.12s - 508.40s: vielen
# 508.40s - 508.52s: Menschen,
# 508.52s - 508.82s: die
# 508.82s - 509.02s: gesagt
# 509.02s - 509.30s: haben,
# 509.48s - 509.70s: so
# 509.70s - 509.96s: jetzt
# 509.96s - 510.20s: nicht,
# 510.28s - 510.42s: nur
# 510.42s - 510.54s: jetzt
# 510.54s - 510.74s: mal
# 510.74s - 510.96s: Schluss.
# 511.46s - 511.62s: Und
# 511.62s - 511.80s: dieses
# 511.80s - 511.90s: so
# 511.90s - 512.00s: ist
# 512.00s - 512.14s: mal
# 512.14s - 512.34s: ein
# 512.34s - 512.62s: Schluss,
# 513.08s - 513.26s: hat
# 513.26s - 513.48s: der
# 513.48s - 513.72s: Linken
# 513.72s - 513.94s: wieder
# 513.94s - 514.08s: eine
# 514.08s - 514.30s: Kraft
# 514.30s - 514.70s: gegeben.
# 516.56s - 517.36s: Verständlich,
# 518.44s - 518.52s: auch
# 518.52s - 518.84s: für
# 518.84s - 519.08s: mich
# 519.08s - 519.54s: emotional
# 519.54s - 519.74s: sehr
# 519.74s - 519.96s: stark
# 519.96s - 520.61s: nachvollziehbar.
# 520.61s - 520.86s: Aber
# 520.86s - 520.94s: ich
# 520.94s - 521.14s: muss
# 521.14s - 521.44s: auch
# 521.44s - 521.76s: sagen,
# 522.20s - 522.34s: das
# 522.34s - 522.48s: kann
# 522.48s - 522.70s: natürlich
# 522.70s - 522.86s: nicht
# 522.86s - 522.94s: das
# 522.94s - 523.20s: letzte
# 523.20s - 523.44s: Wort
# 523.44s - 523.74s: sein.
# 523.74s - 524.42s: Denn
# 524.42s - 524.64s: die
# 524.64s - 524.92s: nächsten
# 524.92s - 525.16s: vier
# 525.16s - 525.38s: Jahre
# 525.38s - 525.62s: dürfen
# 525.62s - 525.90s: nicht
# 525.90s - 526.28s: verschenkt
# 526.28s - 526.56s: werden.
# 527.30s - 527.38s: Und
# 527.38s - 527.40s: wenn
# 527.40s - 527.78s: die
# 527.78s - 528.10s: nächsten
# 528.10s - 528.42s: vier
# 528.42s - 528.80s: Jahre
# 528.80s - 529.40s: in
# 529.40s - 530.14s: den
# 530.14s - 530.72s: Verhandlungen
# 530.72s - 530.94s: zu
# 530.94s - 531.08s: einer
# 531.08s - 531.58s: Regierung,
# 532.12s - 532.82s: gegebenenfalls
# 532.82s - 533.02s: in
# 533.02s - 533.22s: einer
# 533.22s - 533.76s: Regierung,
# 534.66s - 534.96s: keine
# 534.96s - 535.28s: Stimme
# 535.28s - 535.50s: für
# 535.50s - 535.68s: die
# 535.68s - 535.92s: Zukunft
# 535.92s - 536.34s: bekommen,
# 536.46s - 536.66s: dann
# 536.66s - 536.84s: sind
# 536.84s - 537.00s: das
# 537.00s - 537.46s: verschenkte
# 537.46s - 537.76s: Jahre.
# 538.08s - 538.46s: Und
# 538.46s - 538.56s: das
# 538.56s - 539.18s: sind
# 539.18s - 539.48s: die
# 539.48s - 539.86s: Gründe,
# 540.02s - 540.24s: warum
# 540.24s - 540.44s: ich
# 540.44s - 540.66s: jetzt
# 540.66s - 541.02s: überhaupt
# 541.82s - 542.02s: ein
# 542.02s - 543.26s: bisschen
# 543.26s - 543.56s: die
# 543.56s - 544.12s: Fingerspitzen
# 544.12s - 544.58s: motiviert
# 544.58s - 544.69s: bin,
# 544.69s - 544.88s: für
# 544.88s - 545.08s: die
# 545.08s - 545.58s: nächsten
# 545.58s - 546.02s: Tage
# 546.02s - 546.24s: voll
# 546.24s - 546.68s: reinzuhauen.
# 546.92s - 547.20s: Haben
# 547.20s - 547.58s: Sie
# 547.58s - 548.46s: eine
# 548.46s - 548.82s: gewisse
# 548.82s - 549.37s: Resthoffnung,
# 549.37s - 549.84s: dass
# 549.84s - 550.00s: es
# 550.00s - 550.24s: für
# 550.24s - 550.70s: ein
# 550.70s - 551.10s: linkes
# 551.10s - 551.70s: Bündnis,
# 551.84s - 552.52s: also
# 552.52s - 554.84s: rot-grün,
# 554.86s - 555.36s: erreichen
# 555.36s - 555.66s: könnte?
# 556.44s - 556.64s: Ich
# 556.64s - 556.90s: habe
# 556.90s - 557.02s: die
# 557.02s - 557.32s: ganze
# 557.32s - 557.50s: Zeit
# 557.50s - 557.70s: nicht
# 557.70s - 557.82s: auf
# 557.82s - 558.02s: diese
# 558.02s - 558.28s: ganzen
# 558.28s - 558.80s: Umfragen,
# 558.80s - 559.02s: wer
# 559.02s - 559.18s: mit
# 559.18s - 559.54s: wem
# 559.54s - 559.94s: geschielt
# 559.94s - 560.12s: und
# 560.12s - 560.54s: geschaut
# 560.54s - 560.70s: und
# 560.70s - 560.82s: so
# 560.82s - 561.24s: weiter
# 561.24s - 561.62s: machen
# 561.62s - 561.78s: will.
# 561.78s - 561.88s: Wir
# 561.88s - 562.18s: kämpfen
# 562.18s - 562.84s: für
# 562.84s - 563.24s: eine
# 563.24s - 563.76s: Politik,
# 563.80s - 564.14s: die
# 564.14s - 565.14s: verantwortungsbereit
# 565.14s - 565.28s: ist.
# 565.40s - 565.70s: Also
# 565.70s - 566.28s: die
# 566.28s - 566.72s: weiß,
# 566.76s - 566.94s: dass
# 566.94s - 567.10s: es
# 567.10s - 567.32s: weh
# 567.32s - 567.43s: tut.
# 567.43s - 567.66s: Ich
# 567.66s - 567.88s: komme
# 567.88s - 568.14s: aus
# 568.14s - 568.40s: einer
# 568.40s - 568.80s: schwierigen
# 568.80s - 569.22s: Regierung
# 569.78s - 570.04s: und
# 570.04s - 570.22s: will
# 570.22s - 570.36s: die
# 570.36s - 570.60s: Grünen
# 570.60s - 570.74s: auch
# 570.74s - 570.92s: wieder
# 570.92s - 570.98s: in
# 570.98s - 571.22s: eine
# 571.22s - 571.66s: Regierung
# 571.66s - 572.30s: reinführen,
# 572.46s - 572.84s: wissend,
# 572.84s - 572.92s: dass
# 572.92s - 573.08s: es
# 573.08s - 573.34s: schwierig
# 573.34s - 573.56s: wird.
# 573.62s - 573.98s: Alle,
# 574.20s - 574.22s: die
# 574.22s - 574.68s: eingetreten
# 574.68s - 574.88s: sind,
# 575.80s - 575.96s: die
# 575.96s - 576.22s: vielen,
# 576.22s - 576.54s: vielen
# 576.54s - 577.02s: Zehntausend
# 577.02s - 577.13s: Leute,
# 577.13s - 577.32s: die
# 577.32s - 577.38s: bei
# 577.38s - 577.64s: uns
# 577.64s - 578.10s: eingetreten
# 578.10s - 578.28s: sind,
# 578.40s - 578.56s: wissen
# 578.56s - 579.04s: ja,
# 579.08s - 579.36s: dass
# 579.36s - 579.52s: wir
# 579.52s - 579.76s: nicht
# 579.76s - 580.06s: Politik
# 580.06s - 580.26s: für
# 580.26s - 580.38s: die
# 580.38s - 580.70s: Galerie
# 580.70s - 581.02s: machen.
# 581.72s - 582.44s: Und
# 582.44s - 582.60s: dann
# 582.60s - 582.76s: muss
# 582.76s - 582.88s: man
# 582.88s - 583.00s: sehen,
# 583.00s - 583.16s: was
# 583.16s - 583.40s: dabei
# 583.40s - 583.86s: passiert.
# 587.04s - 587.06s: Denn
# 587.06s - 587.12s: die
# 587.12s - 588.18s: politische
# 588.18s - 589.42s: Mehrheitsbildungslage
# 589.54s - 589.64s: ist
# 589.64s - 589.94s: da
# 589.94s - 590.20s: sehr,
# 590.20s - 590.42s: sehr
# 590.42s - 590.90s: unübersichtlich,
# 590.96s - 591.16s: hängt
# 591.16s - 591.34s: davon
# 591.34s - 591.50s: ab,
# 591.50s - 591.68s: wie
# 591.68s - 591.88s: viele
# 591.88s - 592.16s: andere
# 592.16s - 592.52s: Parteien
# 592.52s - 592.72s: noch
# 592.72s - 593.12s: reinkommen,
# 593.18s - 593.30s: ob
# 593.30s - 593.46s: sie
# 593.46s - 593.68s: nicht
# 593.68s - 594.16s: reinkommen,
# 594.38s - 594.64s: wie
# 594.64s - 594.88s: stark
# 594.88s - 595.10s: die
# 595.10s - 595.28s: anderen
# 595.28s - 595.54s: sind.
# 596.08s - 596.16s: Da
# 596.16s - 596.30s: muss
# 596.30s - 596.44s: man
# 596.44s - 596.56s: sich
# 596.56s - 596.68s: jetzt
# 596.68s - 596.74s: auf
# 596.74s - 596.92s: sich
# 596.92s - 597.18s: selbst
# 597.18s - 597.62s: verlassen.
# 598.14s - 598.46s: Das
# 598.46s - 598.64s: ist
# 598.64s - 598.72s: das
# 598.72s - 598.92s: Beste,
# 598.96s - 599.06s: was
# 599.06s - 599.18s: ich
# 599.18s - 599.44s: sagen
# 599.44s - 599.68s: kann.
# 600.00s - 600.20s: Das
# 600.20s - 600.48s: sind
# 600.48s - 600.80s: unsere
# 600.80s - 601.10s: sauren
# 601.10s - 601.46s: Drops,
# 601.56s - 601.60s: Herr
# 601.60s - 601.88s: Habeck.
# 601.92s - 602.14s: Die
# 602.14s - 602.38s: biete
# 602.38s - 602.56s: ich
# 602.56s - 602.82s: Ihnen
# 602.82s - 602.98s: immer
# 602.98s - 603.18s: dann
# 603.18s - 603.38s: an,
# 603.94s - 603.96s: wenn
# 603.96s - 604.64s: Sie
# 604.64s - 604.82s: eine
# 604.82s - 605.08s: Antwort
# 605.08s - 605.32s: aus
# 605.32s - 605.48s: dem
# 605.48s - 605.76s: Wege
# 605.76s - 605.98s: gehen.
# 606.52s - 606.74s: Zu
# 606.74s - 607.32s: Rot-Rot-Grün
# 607.32s - 607.58s: wollten
# 607.58s - 607.78s: Sie
# 607.78s - 608.20s: nichts
# 608.20s - 608.48s: sagen,
# 608.62s - 608.76s: mögen
# 608.76s - 608.96s: Sie
# 608.96s - 609.24s: mal
# 609.24s - 609.96s: einprobieren.
# 610.26s - 610.54s: Die
# 610.54s - 610.74s: sind
# 610.74s - 610.94s: einfach
# 610.94s - 611.24s: sehr
# 611.24s - 611.76s: sauer.
# 612.02s - 612.20s: Das
# 612.20s - 612.22s: ist
# 612.22s - 612.48s: schon
# 612.48s - 612.50s: eine
# 612.50s - 612.78s: Form
# 612.78s - 613.02s: von
# 613.02s - 613.34s: Bestrafung.
# 615.18s - 615.20s: Also
# 615.20s - 615.22s: selbst,
# 615.22s - 615.38s: was
# 615.38s - 615.60s: fragen
# 615.60s - 615.70s: Sie
# 615.70s - 615.84s: mich,
# 615.92s - 616.58s: Rot-Rot-Grün
# 616.58s - 617.00s: hat
# 617.00s - 617.70s: jetzt
# 617.70s - 618.33s: ...
# 618.33s - 618.38s: Gut.
# 618.94s - 618.96s: 36
# 618.96s - 619.08s: Prozent
# 619.08s - 619.22s: oder
# 619.22s - 619.42s: so
# 619.42s - 619.62s: etwas,
# 619.76s - 619.88s: das
# 619.88s - 620.12s: ist
# 620.12s - 620.96s: ...
# 621.14s - 621.26s: Ich
# 621.26s - 621.58s: setze
# 621.58s - 622.50s: meine
# 622.50s - 622.96s: politischen
# 622.96s - 623.26s: Karten
# 623.26s - 623.52s: nicht
# 623.52s - 624.36s: auf
# 624.36s - 624.80s: das
# 624.80s - 625.08s: eine
# 625.08s - 625.62s: Bündnis,
# 625.96s - 626.36s: sondern
# 626.36s - 626.92s: auf
# 626.92s - 627.08s: die
# 627.08s - 627.28s: eigene
# 627.28s - 627.70s: Stärke.
# 627.88s - 628.06s: Und
# 628.06s - 628.26s: zwar
# 628.26s - 628.40s: auf
# 628.40s - 628.58s: eine
# 628.58s - 628.88s: Stärke,
# 628.90s - 629.00s: die
# 629.00s - 629.22s: sich
# 629.22s - 629.70s: unterscheidet
# 629.70s - 629.90s: von
# 629.90s - 630.02s: der
# 630.02s - 630.88s: Linkspartei,
# 631.22s - 631.38s: dass
# 631.38s - 631.68s: wir
# 631.68s - 632.30s: Verantwortung
# 632.30s - 632.68s: und
# 632.68s - 634.10s: Veränderungsbereitschaft
# 634.10s - 634.32s: in
# 634.32s - 634.88s: Energierung
# 634.88s - 635.22s: suchen.
# 635.66s - 635.92s: Und
# 635.92s - 635.98s: dass
# 635.98s - 636.24s: wir
# 636.24s - 636.66s: Inhalte
# 636.66s - 636.98s: bringen,
# 637.20s - 637.24s: die
# 637.24s - 637.46s: in
# 637.46s - 637.76s: der
# 637.76s - 638.10s: Klarheit,
# 638.24s - 638.68s: Entschiedenheit
# 640.10s - 640.18s: und
# 640.18s - 640.80s: energetischen
# 640.80s - 641.74s: Aufgeladenheit
# 641.74s - 642.28s: von
# 642.28s - 642.44s: der
# 642.44s - 642.64s: SPD
# 642.64s - 642.84s: nicht
# 642.84s - 642.96s: zu
# 642.96s - 643.22s: erwarten
# 643.22s - 643.42s: sind.
# 643.70s - 644.00s: Das
# 644.00s - 644.16s: ist
# 644.16s - 644.46s: Grund
# 644.46s - 644.72s: genug,
# 644.82s - 645.00s: meine
# 645.00s - 645.24s: Partei
# 645.24s - 645.36s: zu
# 645.36s - 645.62s: wählen.
# 645.94s - 646.52s: Also,
# 646.56s - 646.66s: do
# 646.66s - 646.84s: the
# 646.84s - 647.08s: math,
# 647.22s - 647.50s: schau
# 647.50s - 647.70s: auf
# 647.70s - 648.00s: die
# 648.00s - 648.22s: Zahlen
# 648.22s - 648.48s: und
# 648.48s - 648.62s: die
# 648.62s - 649.01s: Umfragen.
# 649.01s - 649.22s: Da
# 649.22s - 649.46s: ist
# 649.46s - 649.76s: dann
# 649.76s - 650.10s: die
# 650.10s - 650.62s: realistische
# 650.62s - 650.90s: Rolle
# 650.90s - 651.18s: für
# 651.18s - 651.36s: die
# 651.36s - 651.55s: Grünen,
# 651.55s - 651.78s: dass
# 651.78s - 651.96s: sie
# 651.96s - 652.10s: sich
# 652.10s - 652.36s: noch
# 652.36s - 652.52s: als
# 652.52s - 653.18s: Juniorpartner
# 653.18s - 653.36s: bei
# 653.36s - 653.78s: Friedrich
# 653.78s - 654.44s: Merz
# 654.44s - 655.10s: bewerben
# 655.10s - 655.42s: können.
# 655.84s - 655.92s: Er
# 655.92s - 656.08s: hat
# 656.08s - 656.62s: gestern
# 656.62s - 657.02s: etwas
# 657.02s - 657.78s: doch
# 657.78s - 658.24s: eher
# 658.24s - 659.20s: Unvorteilhaftes
# 659.20s - 659.42s: über
# 659.42s - 659.70s: Sie
# 660.26s - 660.68s: im
# 660.68s - 661.84s: Podcast-Playbook
# 661.84s - 662.08s: von
# 662.08s - 662.96s: Politico
# 662.96s - 663.74s: gesagt.
# 663.76s - 663.94s: Er
# 663.94s - 664.04s: hat
# 664.04s - 664.26s: da
# 664.26s - 664.79s: ausgeschlossen,
# 664.79s - 665.36s: Sie
# 665.36s - 666.08s: erneut
# 666.08s - 666.52s: zum
# 666.52s - 667.50s: Wirtschaftsminister
# 667.50s - 667.72s: zu
# 667.72s - 667.92s: machen.
# 668.02s - 668.14s: Und
# 668.14s - 668.42s: seine
# 668.42s - 668.96s: Begründung
# 668.96s - 669.14s: ist
# 669.14s - 669.36s: schon
# 669.36s - 669.80s: pikant.
# 669.86s - 670.08s: Wer
# 670.08s - 670.44s: käme
# 670.44s - 670.64s: denn
# 670.64s - 670.88s: auf
# 670.88s - 671.08s: die
# 671.08s - 671.28s: Idee,
# 671.34s - 671.58s: einen
# 671.58s - 672.14s: gescheiterten
# 672.14s - 672.92s: Bundesminister
# 672.92s - 673.46s: erneut
# 673.46s - 673.62s: in
# 673.62s - 673.78s: ein
# 673.78s - 674.08s: Ressort
# 674.08s - 674.32s: zu
# 674.32s - 674.62s: setzen,
# 675.02s - 675.52s: dessen
# 675.52s - 675.76s: Teil
# 675.76s - 676.04s: er
# 676.04s - 676.30s: nun
# 676.30s - 676.76s: wirklich
# 676.76s - 677.30s: vollkommen
# 677.30s - 678.66s: untergeflügt
# 678.66s - 678.86s: hat?
# 678.86s - 679.18s: Und
# 679.18s - 679.70s: dann
# 679.70s - 680.32s: noch
# 680.32s - 680.68s: der
# 680.68s - 680.96s: schöne
# 680.96s - 681.44s: Nachsatz,
# 681.48s - 681.88s: Ludwig
# 681.88s - 682.30s: Erhard
# 682.30s - 682.58s: hätte
# 682.58s - 682.84s: sich
# 682.84s - 683.20s: im
# 683.20s - 683.92s: Grabe
# 683.92s - 684.46s: umgedreht,
# 684.46s - 684.76s: wenn
# 684.76s - 684.86s: er
# 684.86s - 685.10s: das
# 685.10s - 685.70s: noch
# 685.70s - 686.74s: mitbekommen
# 686.74s - 687.24s: hätte.
# 688.84s - 689.04s: Ist
# 689.04s - 689.68s: das
# 689.68s - 689.94s: etwas,
# 690.00s - 690.16s: was
# 690.16s - 690.38s: Sie
# 690.38s - 690.46s: dann
# 690.46s - 690.70s: doch
# 690.70s - 690.96s: kalt
# 690.96s - 691.34s: erwischt?
# 691.48s - 691.74s: Eine
# 691.74s - 692.24s: solche
# 692.24s - 692.64s: harte
# 692.64s - 693.12s: Aussage?
# 693.94s - 693.96s: Es
# 693.96s - 694.42s: zeigt
# 694.42s - 694.72s: vor
# 694.72s - 694.86s: allem,
# 694.96s - 695.08s: dass
# 695.08s - 695.36s: Friedrich
# 695.36s - 695.58s: Merz
# 695.58s - 695.74s: immer
# 695.74s - 695.86s: noch
# 695.86s - 696.06s: nicht
# 696.06s - 696.44s: verstanden
# 696.44s - 696.64s: hat,
# 696.64s - 696.94s: wie
# 696.94s - 697.14s: tief
# 697.14s - 697.38s: die
# 697.38s - 697.82s: Wirtschaftskrise
# 697.82s - 698.50s: einschneidet.
# 698.90s - 699.56s: Das
# 699.56s - 699.72s: ist
# 699.72s - 699.94s: das
# 699.94s - 700.46s: Dramatische.
# 701.38s - 701.44s: Alle
# 701.44s - 702.50s: Kabinettsposten
# 702.50s - 702.80s: und
# 702.80s - 703.26s: Personen
# 703.44s - 703.76s: werden
# 703.76s - 704.10s: immer
# 704.10s - 704.36s: nach
# 704.36s - 705.02s: einer
# 705.02s - 705.96s: Koalitionsverhandlung
# 705.96s - 706.28s: geführt.
# 706.34s - 706.50s: Da
# 706.50s - 706.66s: sind
# 706.66s - 706.80s: wir
# 706.80s - 707.02s: noch
# 707.02s - 707.16s: lange
# 707.16s - 707.34s: nicht.
# 708.28s - 708.46s: Er
# 708.46s - 708.84s: kann
# 708.84s - 709.18s: nicht
# 709.18s - 709.72s: ausschließen,
# 709.76s - 709.94s: dass
# 709.94s - 710.74s: Sie
# 710.74s - 710.94s: noch
# 710.94s - 711.10s: mal
# 711.10s - 711.80s: Wirtschaftsminister
# 711.80s - 712.08s: werden.
# 712.92s - 713.50s: Jedenfalls
# 713.50s - 713.92s: entscheiden
# 713.92s - 714.12s: die
# 714.12s - 714.62s: Parteien
# 714.62s - 715.20s: über
# 715.20s - 716.24s: ihre
# 716.24s - 716.74s: Personen
# 716.74s - 717.14s: selbst.
# 717.70s - 717.84s: Und
# 717.84s - 718.04s: die
# 718.04s - 718.42s: Ressorts
# 718.42s - 718.76s: werden
# 718.76s - 718.92s: in
# 718.92s - 719.04s: der
# 719.04s - 719.22s: Regel
# 719.22s - 719.48s: nach
# 719.48s - 720.04s: Verhandlungen
# 720.04s - 720.50s: durchgeführt.
# 720.50s - 720.70s: Wir
# 720.70s - 720.84s: sind
# 720.84s - 721.00s: noch
# 721.00s - 721.08s: nicht
# 721.08s - 721.18s: mehr
# 721.18s - 721.30s: im
# 721.30s - 722.14s: Verhandlungsmodus.
# 723.06s - 723.08s: Also,
# 723.14s - 723.32s: das
# 723.32s - 723.34s: ist
# 723.34s - 724.06s: alles
# 724.06s - 724.84s: kühngesprochen.
# 726.44s - 726.56s: Und
# 726.56s - 726.74s: das
# 726.74s - 727.64s: politisch
# 727.64s - 728.28s: Dramatische
# 728.28s - 728.66s: dahinter
# ...
# 3572.00s - 3572.20s: werden
# 3572.20s - 3572.40s: in
# 3572.40s - 3572.82s: Europa
# 3572.82s - 3573.02s: und
# 3573.02s - 3573.16s: in
# 3573.16s - 3573.32s: Deutschland.
# 3573.40s - 3573.56s: Die
# 3573.56s - 3573.74s: anderen
# 3573.74s - 3574.04s: warten
# 3574.04s - 3574.38s: nicht
# 3574.38s - 3574.56s: auf
# 3574.56s - 3574.68s: uns.
# 3574.74s - 3574.86s: Das
# 3574.86s - 3575.08s: sehen
# 3575.08s - 3575.22s: wir,
# 3575.30s - 3575.46s: was
# 3575.46s - 3575.66s: da
# 3575.66s - 3575.76s: um
# 3575.76s - 3575.96s: uns
# 3575.96s - 3576.14s: herum
# 3576.14s - 3576.54s: passiert.
# 3576.62s - 3576.76s: Und
# 3576.76s - 3576.86s: wenn
# 3576.86s - 3577.02s: wir
# 3577.02s - 3577.20s: nicht
# 3577.20s - 3577.32s: mehr
# 3577.32s - 3577.72s: irgendwann
# 3577.72s - 3578.24s: eingeladen
# 3578.24s - 3578.46s: werden
# 3578.46s - 3578.60s: wollen,
# 3578.64s - 3578.90s: sondern
# 3578.90s - 3579.14s: wieder
# 3579.14s - 3579.38s: selber
# 3579.38s - 3579.64s: die
# 3579.64s - 3580.20s: Einladenden
# 3580.20s - 3580.37s: sind.
# 3580.37s - 3580.66s: Das
# 3580.66s - 3580.80s: ist
# 3580.80s - 3580.92s: ja
# 3580.92s - 3581.16s: die
# 3581.16s - 3582.04s: Gedankfigur
# 3582.04s - 3582.50s: Trump
# 3582.50s - 3582.98s: und
# 3582.98s - 3583.30s: Putin,
# 3583.36s - 3584.10s: beziehungsweise
# 3584.10s - 3584.62s: Lavrov
# 3584.62s - 3585.10s: und
# 3585.10s - 3585.64s: Rubio,
# 3585.72s - 3585.94s: die
# 3585.94s - 3586.42s: Außenminister
# 3586.42s - 3586.74s: treffen
# 3586.74s - 3586.98s: sich
# 3586.98s - 3587.22s: jetzt.
# 3587.58s - 3587.82s: Und
# 3587.82s - 3588.04s: wir
# 3588.04s - 3588.44s: beklagen
# 3588.44s - 3588.66s: uns
# 3588.66s - 3588.90s: darüber,
# 3589.20s - 3589.34s: dass
# 3589.34s - 3589.46s: wir
# 3589.46s - 3589.70s: nicht
# 3589.70s - 3590.12s: eingeladen
# 3590.12s - 3590.36s: sind.
# 3590.60s - 3590.80s: Das
# 3590.80s - 3590.92s: ist
# 3590.92s - 3591.04s: ja
# 3591.04s - 3591.20s: schon
# 3591.20s - 3591.34s: der
# 3591.34s - 3591.56s: erste
# 3591.56s - 3591.96s: gedankliche
# 3591.96s - 3592.20s: Fehler.
# 3592.28s - 3592.58s: Wir
# 3592.58s - 3592.92s: müssen
# 3592.92s - 3593.34s: diejenigen
# 3593.34s - 3593.58s: sein,
# 3593.66s - 3593.78s: die
# 3593.78s - 3593.94s: sagen,
# 3593.96s - 3594.40s: wir
# 3594.40s - 3594.78s: laden
# 3594.78s - 3594.94s: ein.
# 3595.08s - 3595.44s: Wir
# 3595.44s - 3595.98s: organisieren
# 3595.98s - 3596.16s: das
# 3596.16s - 3596.40s: ganze
# 3596.40s - 3596.56s: Ding.
# 3597.30s - 3597.60s: Das
# 3597.60s - 3597.86s: meine
# 3597.86s - 3598.02s: ich
# 3598.02s - 3598.70s: mit
# 3598.70s - 3599.12s: gewinnen
# 3599.12s - 3599.34s: wollen
# 3599.34s - 3599.54s: und
# 3599.54s - 3599.64s: nicht
# 3599.64s - 3599.76s: nur
# 3599.76s - 3599.84s: immer
# 3599.84s - 3599.86s: nur
# 3599.86s - 3599.88s: gewinnen
# 3599.88s - 3599.90s: wollen.
# 3600.00s - 3600.26s: nicht
# 3600.26s - 3600.74s: verlieren
# 3600.74s - 3601.02s: wollen.
# 3601.34s - 3601.54s: Das
# 3601.54s - 3601.78s: meine
# 3601.78s - 3601.90s: ich
# 3601.90s - 3602.96s: mit
# 3602.96s - 3604.02s: nichts
# 3604.02s - 3604.28s: Gutes
# 3604.28s - 3604.52s: außer
# 3604.52s - 3604.72s: man
# 3604.72s - 3604.92s: tut
# 3604.92s - 3605.16s: es.
# 3605.82s - 3605.84s: Also
# 3605.84s - 3607.22s: dieser
# 3607.22s - 3608.90s: Wille
# 3608.90s - 3609.08s: zum
# 3609.16s - 3609.56s: Erfolg,
# 3609.60s - 3609.86s: der
# 3609.86s - 3610.00s: darf
# 3610.00s - 3610.16s: uns
# 3610.16s - 3610.30s: nicht
# 3610.30s - 3610.72s: abhanden
# 3610.72s - 3610.88s: kommen.
# 3611.02s - 3611.14s: Aber
# 3611.14s - 3611.26s: der
# 3611.26s - 3611.50s: bedeutet
# 3611.50s - 3611.80s: eben
# 3611.80s - 3612.06s: auch
# 3612.06s - 3612.26s: bereit
# 3612.26s - 3612.42s: zu
# 3612.42s - 3612.54s: sein,
# 3612.54s - 3612.68s: im
# 3612.68s - 3613.04s: Zweifelsfall
# 3613.04s - 3613.26s: sich
# 3613.26s - 3613.74s: unpopulär
# 3613.74s - 3613.88s: zu
# 3613.88s - 3614.06s: machen
# 3614.06s - 3614.22s: und
# 3614.22s - 3614.34s: die
# 3614.34s - 3614.52s: Dinge
# 3614.52s - 3615.12s: auszusprechen,
# 3615.30s - 3615.44s: die
# 3615.44s - 3615.66s: im
# 3615.66s - 3615.96s: Wahlkampf
# 3615.96s - 3616.11s: nichts
# 3616.11s - 3616.28s: zu
# 3616.28s - 3616.42s: suchen
# 3616.42s - 3616.76s: haben.
# 3617.18s - 3617.38s: Nach
# 3617.38s - 3617.60s: dem
# 3617.60s - 3617.96s: Lehrbuch
# 3617.96s - 3618.16s: des
# 3618.16s - 3619.16s: Wahlkampfes.
# 3619.32s - 3619.90s: Wir
# 3619.90s - 3620.28s: haben
# 3620.28s - 3620.60s: auch
# 3620.60s - 3620.72s: in
# 3620.72s - 3620.94s: der
# 3620.94s - 3621.38s: Vergangenheit
# 3621.38s - 3621.62s: schon
# 3621.62s - 3622.04s: häufiger
# 3622.20s - 3622.70s: miteinander
# 3622.70s - 3623.28s: gesprochen.
# 3623.96s - 3624.14s: Und
# 3624.14s - 3624.30s: ich
# 3624.30s - 3624.60s: habe
# 3624.60s - 3624.78s: in
# 3624.78s - 3625.28s: Erinnerung,
# 3625.40s - 3625.54s: dass
# 3625.54s - 3625.82s: Sie
# 3625.82s - 3626.24s: immer
# 3626.24s - 3627.20s: auch
# 3627.20s - 3627.48s: von
# 3627.48s - 3627.76s: einem
# 3627.76s - 3628.22s: anderen
# 3628.54s - 3629.54s: Politikansatz
# 3629.54s - 3630.04s: gesprochen
# 3630.04s - 3630.34s: haben,
# 3630.42s - 3630.54s: der
# 3630.54s - 3630.86s: Ihnen
# 3630.86s - 3631.74s: persönlich
# 3631.74s - 3632.68s: vorschwebt.
# 3632.78s - 3633.00s: Einer
# 3633.00s - 3633.34s: anderen
# 3633.34s - 3633.82s: Sprache
# 3633.82s - 3633.92s: in
# 3633.92s - 3634.08s: der
# 3634.08s - 3634.48s: Politik,
# 3634.58s - 3634.86s: einer
# 3634.86s - 3635.20s: anderen
# 3635.20s - 3636.10s: Kommunikation,
# 3636.30s - 3636.58s: auch
# 3636.58s - 3636.92s: ein
# 3636.92s - 3637.44s: anderer
# 3637.44s - 3638.20s: Umgang
# 3638.20s - 3639.00s: miteinander
# 3639.00s - 3639.30s: unter
# 3639.30s - 3639.58s: den
# 3639.58s - 3640.22s: Handelnden
# 3640.22s - 3640.96s: in
# 3640.96s - 3641.09s: der
# 3641.09s - 3641.70s: Politik.
# 3642.00s - 3642.26s: Nach
# 3642.26s - 3642.80s: dreieinhalb
# 3642.80s - 3643.08s: Jahren
# 3643.08s - 3643.30s: an
# 3643.30s - 3643.72s: der
# 3643.72s - 3644.24s: Regierung.
# 3644.34s - 3644.96s: Ist
# 3644.96s - 3645.70s: Ihr
# 3645.70s - 3646.22s: etwas
# 3646.22s - 3646.96s: idealistischer
# 3646.96s - 3648.06s: Ansatz
# 3648.06s - 3648.68s: an
# 3648.68s - 3649.00s: Grenzen
# 3649.02s - 3649.50s: gestoßen?
# 3650.04s - 3650.24s: Ja,
# 3650.30s - 3650.36s: an
# 3650.36s - 3650.60s: Grenzen
# 3650.60s - 3650.96s: gestoßen
# 3650.96s - 3651.12s: ist
# 3651.12s - 3651.24s: er.
# 3651.28s - 3651.46s: Das
# 3651.46s - 3651.64s: war
# 3651.64s - 3651.82s: aber
# 3651.82s - 3652.04s: auch
# 3652.04s - 3653.22s: nicht
# 3653.22s - 3654.32s: überraschend,
# 3654.80s - 3654.82s: denn
# 3654.82s - 3655.26s: das
# 3655.26s - 3655.44s: ist
# 3655.44s - 3655.64s: ja
# 3655.94s - 3656.30s: auch
# 3656.30s - 3656.52s: eine
# 3656.52s - 3657.04s: Machtfrage
# 3657.04s - 3657.28s: und
# 3657.28s - 3657.44s: eine
# 3657.44s - 3658.14s: Machtansage.
# 3658.50s - 3658.54s: Also
# 3658.54s - 3658.76s: wenn
# 3658.76s - 3659.10s: man,
# 3659.90s - 3660.34s: wenn
# 3660.34s - 3660.68s: ich,
# 3660.72s - 3660.84s: ich
# 3660.84s - 3661.00s: rede
# 3661.00s - 3661.22s: mal
# 3661.22s - 3661.40s: von
# 3661.40s - 3661.80s: mir
# 3661.80s - 3661.90s: sage,
# 3661.90s - 3662.40s: im
# 3662.40s - 3663.14s: Zweifelsfall
# 3663.14s - 3663.44s: müssen
# 3663.44s - 3663.92s: Politiker
# 3663.92s - 3664.76s: auch
# 3664.76s - 3665.58s: die
# 3665.58s - 3665.84s: Stärke
# 3665.84s - 3666.12s: haben,
# 3666.30s - 3666.46s: Fehler
# 3666.46s - 3667.00s: zuzugeben,
# 3667.06s - 3667.22s: zu
# 3667.22s - 3667.38s: sagen,
# 3667.40s - 3667.54s: wir
# 3667.54s - 3667.86s: lernen,
# 3668.12s - 3668.36s: wir
# 3668.36s - 3668.86s: korrigieren
# 3668.86s - 3669.60s: Entscheidungen,
# 3669.86s - 3669.96s: wir
# 3669.96s - 3670.12s: geben
# 3670.12s - 3670.28s: dem
# 3670.28s - 3670.52s: anderen
# 3670.52s - 3670.72s: auch
# 3670.72s - 3670.98s: einen
# 3670.98s - 3671.26s: Punkt,
# 3671.46s - 3671.76s: sagen,
# 3672.22s - 3672.46s: gut
# 3672.46s - 3672.76s: gesehen,
# 3673.18s - 3673.42s: hätte
# 3673.42s - 3673.52s: ich
# 3673.52s - 3673.70s: früher
# 3673.70s - 3673.92s: nicht
# 3673.92s - 3674.08s: gedacht.
# 3674.18s - 3674.24s: Ich
# 3674.24s - 3674.36s: habe
# 3674.36s - 3674.44s: es
# 3674.44s - 3674.60s: vorhin
# 3674.60s - 3674.74s: bei
# 3674.74s - 3674.88s: der
# 3674.88s - 3675.18s: FDP
# 3675.18s - 3675.56s: gesagt
# 3675.56s - 3675.74s: und
# 3675.74s - 3675.92s: gesagt,
# 3676.44s - 3676.46s: dieses
# 3676.46s - 3677.56s: Sondervermögen
# 3677.56s - 3678.10s: Aktien,
# 3678.20s - 3678.36s: da
# 3678.36s - 3678.50s: war
# 3678.50s - 3678.60s: ich
# 3678.60s - 3678.84s: zuerst
# 3678.84s - 3679.22s: skeptisch,
# 3680.10s - 3680.12s: aber
# 3680.12s - 3680.56s: ich
# 3680.56s - 3680.78s: leicht
# 3680.78s - 3681.58s: modifiziert
# 3681.58s - 3682.00s: übernehme
# 3682.00s - 3682.10s: ich
# 3682.10s - 3682.28s: das
# 3682.28s - 3682.52s: jetzt.
# 3683.18s - 3683.36s: Dann
# 3683.40s - 3683.56s: ist
# 3683.56s - 3683.64s: es
# 3683.64s - 3684.30s: natürlich
# 3684.30s - 3684.96s: auch
# 3684.96s - 3685.18s: eine
# 3685.18s - 3685.84s: Kampfansage
# 3685.84s - 3686.00s: an
# 3686.00s - 3686.24s: all
# 3686.24s - 3686.64s: diejenigen,
# 3686.68s - 3686.92s: die
# 3686.92s - 3687.42s: immer
# 3687.42s - 3687.60s: nur
# 3687.60s - 3687.82s: recht
# 3687.82s - 3688.04s: haben,
# 3688.06s - 3688.24s: die
# 3688.24s - 3688.38s: immer
# 3688.38s - 3688.64s: glauben,
# 3688.74s - 3688.84s: die
# 3688.84s - 3689.02s: anderen
# 3689.02s - 3689.22s: sind
# 3689.22s - 3689.56s: schuld,
# 3689.66s - 3689.78s: die
# 3689.78s - 3689.96s: immer
# 3689.96s - 3690.16s: die
# 3690.16s - 3690.46s: Verantwortung
# 3690.46s - 3690.68s: bei
# 3690.68s - 3690.90s: anderen
# 3690.90s - 3691.20s: Anlagen
# 3691.20s - 3692.14s: abladen
# 3692.14s - 3692.42s: wollen
# 3692.42s - 3693.48s: und
# 3693.48s - 3694.92s: das
# 3694.92s - 3695.16s: spüren
# 3695.16s - 3695.32s: die
# 3695.32s - 3695.66s: natürlich
# 3695.66s - 3695.94s: auch.
# 3695.98s - 3696.52s: Also
# 3696.52s - 3696.82s: ich
# 3696.82s - 3697.00s: würde
# 3697.00s - 3697.20s: sagen,
# 3697.28s - 3697.42s: das
# 3697.42s - 3698.02s: Gegenmodell,
# 3698.26s - 3698.46s: weil
# 3698.46s - 3698.60s: wir
# 3698.60s - 3698.72s: jetzt
# 3698.72s - 3698.82s: die
# 3698.82s - 3699.00s: Seite
# 3699.00s - 3699.22s: gerade
# 3699.22s - 3699.70s: überblättert
# 3699.70s - 3699.82s: haben,
# 3699.94s - 3700.04s: ist
# 3700.04s - 3700.24s: Markus
# 3700.24s - 3700.54s: Söder,
# 3700.64s - 3700.90s: der
# 3700.90s - 3701.40s: immer
# 3701.40s - 3701.96s: nur
# 3701.96s - 3702.34s: sagt,
# 3702.36s - 3702.54s: die
# 3702.54s - 3702.76s: anderen
# 3702.76s - 3703.00s: müssen
# 3703.00s - 3703.18s: was
# 3703.18s - 3703.40s: anderes
# 3703.40s - 3703.64s: machen,
# 3703.72s - 3703.82s: bei
# 3703.82s - 3703.96s: mir
# 3703.96s - 3704.06s: ist
# 3704.06s - 3704.26s: alles
# 3704.26s - 3704.60s: toll.
# 3705.60s - 3705.76s: Wäre
# 3705.76s - 3706.04s: völlig
# 3706.04s - 3706.46s: unwahrscheinlich,
# 3706.48s - 3706.66s: wenn
# 3706.66s - 3706.74s: es
# 3706.74s - 3706.84s: so
# 3706.84s - 3706.96s: wäre.
# 3707.06s - 3707.30s: Jedenfalls
# 3707.30s - 3707.42s: so
# 3707.42s - 3707.68s: viele
# 3707.68s - 3708.30s: Windkraftanlagen
# 3708.30s - 3708.44s: hat
# 3708.44s - 3708.54s: er
# 3708.54s - 3708.68s: nicht
# 3708.68s - 3709.06s: hinbekommen
# 3709.06s - 3709.20s: und
# 3709.20s - 3709.42s: Bayern
# 3709.42s - 3709.58s: ist
# 3709.58s - 3709.74s: ein
# 3709.74s - 3710.06s: super
# 3710.08s - 3710.68s: Importeurland
# 3710.68s - 3711.88s: von
# 3711.88s - 3712.26s: Strom.
# 3713.42s - 3713.94s: Das
# 3713.94s - 3714.14s: war
# 3714.14s - 3714.34s: nicht
# 3714.34s - 3714.48s: toll,
# 3714.56s - 3714.64s: das
# 3714.64s - 3714.80s: war
# 3714.80s - 3714.84s: schlecht.
# 3714.84s - 3715.54s: Habe
# 3715.54s - 3715.68s: ich
# 3715.68s - 3715.98s: mal
# 3715.98s - 3716.42s: angenommen,
# 3716.66s - 3716.72s: Sie
# 3716.72s - 3716.96s: werden
# 3716.96s - 3717.20s: nicht
# 3717.20s - 3717.82s: Bundeskanzler
# 3717.82s - 3718.00s: und
# 3718.00s - 3718.16s: die
# 3718.16s - 3718.84s: Grünen
# 3718.84s - 3719.26s: sind
# 3719.26s - 3719.52s: sogar
# 3719.52s - 3719.88s: nach
# 3719.88s - 3720.06s: der
# 3720.06s - 3720.22s: Wahl
# 3720.22s - 3720.40s: in
# 3720.40s - 3720.53s: der
# 3720.53s - 3721.44s: Opposition.
# 3721.76s - 3722.14s: Sagen
# 3722.14s - 3722.44s: Sie
# 3722.44s - 3722.96s: persönlich
# 3722.96s - 3723.28s: der
# 3723.28s - 3724.06s: Spitzenpolitik
# 3724.06s - 3724.40s: dann
# 3724.40s - 3724.66s: adieu?
# 3725.68s - 3726.08s: Mein
# 3726.08s - 3726.44s: ganzer
# 3726.44s - 3726.70s: Fokus
# 3726.70s - 3726.84s: ist
# 3726.84s - 3727.02s: jetzt
# 3727.02s - 3727.14s: auf
# 3727.14s - 3727.30s: die
# 3727.30s - 3727.76s: Bundestagswahl
# 3727.76s - 3728.18s: gerichtet
# 3728.18s - 3728.78s: und
# 3728.78s - 3729.04s: das
# 3729.04s - 3729.32s: ist,
# 3729.50s - 3729.82s: das
# 3729.82s - 3729.88s: habe
# 3729.88s - 3729.98s: ich
# 3729.98s - 3730.08s: ja
# 3730.08s - 3730.42s: gesagt,
# 3731.80s - 3732.02s: im
# 3732.02s - 3732.32s: gewissen
# 3732.32s - 3732.56s: Sinne
# 3732.56s - 3732.96s: kämpfe
# 3732.96s - 3733.10s: ich
# 3733.10s - 3733.34s: auch
# 3733.34s - 3733.54s: darum,
# 3733.70s - 3733.82s: dass
# 3733.82s - 3734.22s: das
# 3734.22s - 3734.42s: von
# 3734.42s - 3734.64s: dem
# 3734.64s - 3735.24s: Stil,
# 3735.70s - 3735.86s: dann
# 3735.86s - 3735.98s: nehme
# 3735.98s - 3736.04s: ich
# 3736.04s - 3736.12s: auch
# 3736.12s - 3736.30s: gerne
# 3736.30s - 3736.60s: zwei,
# 3737.30s - 3737.50s: aber
# 3737.50s - 3737.64s: es
# 3737.64s - 3740.42s: ist
# 3740.42s - 3740.50s: nicht
# 3740.50s - 3741.32s: ausweichen,
# 3741.42s - 3741.56s: weil
# 3741.56s - 3741.68s: ich
# 3741.68s - 3741.86s: was
# 3741.86s - 3742.06s: zu
# 3742.06s - 3742.44s: verschweigen
# 3742.44s - 3742.64s: hätte.
# 3742.72s - 3742.82s: Es
# 3742.82s - 3743.00s: ist
# 3743.00s - 3743.20s: einfach
# 3743.20s - 3743.31s: so,
# 3743.31s - 3743.62s: dass
# 3743.62s - 3744.80s: ich
# 3744.80s - 3745.12s: alle
# 3745.12s - 3745.64s: meine
# 3745.64s - 3746.04s: Chips
# 3746.04s - 3746.30s: jetzt
# 3746.30s - 3746.66s: auf
# 3746.66s - 3746.88s: diese
# 3746.88s - 3747.24s: Karte,
# 3747.26s - 3747.44s: auf
# 3747.44s - 3747.70s: dieses
# 3747.70s - 3748.00s: Datum
# 3748.00s - 3748.74s: setze
# 3748.74s - 3749.48s: und
# 3749.48s - 3750.40s: hoffe,
# 3750.46s - 3750.58s: dass
# 3750.58s - 3750.74s: das
# 3750.74s - 3751.04s: gesehen
# 3751.04s - 3751.16s: und
# 3751.16s - 3751.40s: genommen
# 3751.40s - 3751.84s: wird.
# 3752.80s - 3753.06s: Wenn
# 3753.06s - 3753.48s: Friedrich
# 3753.48s - 3753.80s: Merz
# 3753.80s - 3754.22s: Ihnen
# 3754.22s - 3755.28s: überraschend
# 3755.28s - 3755.83s: anbieten
# 3755.83s - 3756.22s: würde,
# 3756.60s - 3756.78s: Sie
# 3756.78s - 3757.04s: zum
# 3757.04s - 3757.94s: Bundespräsidenten
# 3757.94s - 3758.12s: zu
# 3758.12s - 3758.40s: machen,
# 3759.14s - 3759.32s: wie
# 3759.32s - 3759.48s: würden
# 3759.48s - 3759.70s: Sie
# 3759.70s - 3760.14s: reagieren?
# 3760.74s - 3761.00s: Das
# 3761.00s - 3761.30s: ist
# 3761.30s - 3762.42s: ja
# 3762.42s - 3766.02s: hypothetische
# 3766.02s - 3766.48s: Frage.
# 3768.68s - 3768.98s: Ich
# 3768.98s - 3769.22s: weiß
# 3769.22s - 3769.34s: gar
# 3769.34s - 3769.40s: nicht,
# 3769.48s - 3769.54s: wann
# 3769.54s - 3769.64s: die
# 3769.64s - 3769.78s: nächsten
# 3769.78s - 3770.63s: Bundespräsidentenwahlen
# 3770.63s - 3770.90s: sind.
# 3770.92s - 3771.12s: Ich
# 3771.12s - 3771.38s: will
# 3771.38s - 3772.34s: gerne,
# 3772.36s - 3772.74s: dass
# 3772.74s - 3773.96s: wir
# 3773.96s - 3774.26s: ein
# 3774.26s - 3774.90s: starkes,
# 3775.08s - 3775.36s: maximal
# 3775.36s - 3775.78s: starkes
# 3775.78s - 3776.04s: Grünes
# 3776.04s - 3776.38s: Ergebnis
# 3776.38s - 3776.76s: bekommen.
# 3777.00s - 3777.24s: Nochmal,
# 3777.24s - 3777.62s: ich
# 3777.62s - 3778.04s: wiederhole
# 3778.04s - 3778.32s: mich,
# 3778.50s - 3778.62s: weil
# 3778.62s - 3778.82s: wir
# 3778.82s - 3778.98s: die
# 3778.98s - 3779.22s: Partei
# 3779.22s - 3779.34s: sind,
# 3779.36s - 3779.52s: die
# 3779.52s - 3779.78s: die
# 3779.78s - 3780.74s: Verantwortungsbereitschaft
# 3780.74s - 3781.14s: mit
# 3781.14s - 3781.41s: der
# 3781.41s - 3782.26s: Veränderungsbereitschaft
# 3782.26s - 3782.80s: kombinieren.
# 3782.88s - 3783.02s: Das
# 3783.02s - 3783.20s: sehe
# 3783.20s - 3783.30s: ich
# 3783.30s - 3783.48s: wieder
# 3783.48s - 3783.68s: bei
# 3783.68s - 3783.86s: den
# 3783.86s - 3784.02s: anderen
# 3784.02s - 3784.70s: Parteien
# 3784.70s - 3784.98s: in
# 3784.98s - 3785.12s: der
# 3785.12s - 3785.22s: einen
# 3785.22s - 3785.34s: noch
# 3785.34s - 3785.50s: in
# 3785.50s - 3785.54s: der
# 3785.54s - 3785.68s: anderen
# 3785.68s - 3786.02s: Richtung.
# 3786.56s - 3786.78s: Herr
# 3786.78s - 3787.32s: Habeck,
# 3787.42s - 3787.58s: ich
# 3787.58s - 3787.82s: danke
# 3787.82s - 3788.00s: Ihnen
# 3788.00s - 3788.14s: für
# 3788.14s - 3788.34s: das
# 3788.34s - 3788.72s: Gespräch.
# 3788.84s - 3789.10s: Gerne.

# %%
import json

output_filename = "transcription_Robert_Habeck.json"

with open(output_filename, "w", encoding="utf-8") as f:
    json.dump(final_transcript, f, ensure_ascii=False, indent=4)

print(f"Saved to {output_filename}")
# Out:
# Saved to transcription_Robert_Habeck.json

# %%
# Extract transcribed text from all chunks
transcribed_text = "\n".join(chunk["text"] for chunk in final_transcript)

# Save to file
with open("transcription.txt", "w", encoding="utf-8") as file:
    file.write(transcribed_text)

# %%
# Merge speaker diarization and transcription
diarization_segments = []
min_duration = 1.0  #Minimum duration for a speach in seconds
tolerance = 0.2  # Allows small deviations for the first words

for segment, _, speaker in diarization.itertracks(yield_label=True):
    segment_duration = segment.end - segment.start
    if segment_duration >= min_duration:
        diarization_segments.append((segment.start, segment.end, speaker))

active_speaker = None
combined_output = []
merged_start = None
merged_end = None
merged_speaker = None
merged_text = []

# Check which speaker is assigned to each word in the transcription
for segment in final_transcript:
    for word in segment.get("words", []):
        current_time = word["start"]

        # Find the matching speaker segment based on the timestamps
        closest_speaker = None
        for start, end, speaker in diarization_segments:
            # Check whether the word is within a segment or just before it (tolerance)
            if start - tolerance <= current_time <= end:
                closest_speaker = speaker
                break 

        # When a speaker has been found
        if closest_speaker is not None:
            # If the speaker changes or no speaker is set yet
            if active_speaker != closest_speaker:
                # If there has been a change of speaker, write the previous text
                if merged_speaker:
                    speaker_name = speaker_names.get(merged_speaker, "Unknown Speaker")
                    combined_output.append(f"{speaker_name}: {' '.join(merged_text)}")
                
                # Set variables for the new speaker
                merged_speaker = closest_speaker
                merged_start = word["start"]
                merged_end = word["end"]
                merged_text = [word["text"]]
                active_speaker = closest_speaker  # Update active speaker
            else:
                # If the speaker remains the same, add the word
                merged_end = word["end"]
                merged_text.append(word["text"])
        else:
            # If no speaker can be assigned, append the word to the last speaker
            if merged_speaker:
                merged_text.append(word["text"])

# Add last merged speaker, if present
if merged_speaker:
    speaker_name = speaker_names.get(merged_speaker, "Unknown Speaker")
    combined_output.append(f"{speaker_name}: {' '.join(merged_text)}")

# Save output
output_file = "combined_output.txt"
with open(output_file, "w", encoding="utf-8") as f:
    for line in combined_output:
        f.write(line + "\n")
